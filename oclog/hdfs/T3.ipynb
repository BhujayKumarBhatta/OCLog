# %%
import random
# from hdflogv2 import HDFSLogv2
from hdflogv3 import HDFSLogv3
import tensorflow as tf
import numpy as np
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
import pickle
from keras.preprocessing.sequence import pad_sequences
tf.random.set_seed(123)
np.random.seed(123)

# %%
def test_model(ablation=1000, batch_size=32, epochs=3, filters=64, kernel_size=3, dense_neurons=2048, 
              conv1d_set1=1, conv1d_set2=1, maxpool_1=False, hdfs_obJ_full_name=None):
    # from hdflogv2 import HDFSLogv2
    import tensorflow as tf
    import numpy as np
    tf.random.set_seed(123)
    import pickle
    with open(hdfs_obJ_full_name, 'rb') as f:
        hdfslogs = pickle.load(f)    
    # x_train, y_train, x_val, y_val, x_test, y_test 
    train_data, val_data, test_data = hdfslogs.get_tensor_train_val_test(ablation=ablation, batch_size=batch_size)    
    print(train_data)
    B = batch_size
    # B = train_data.element_spec[0].shape[0]
    seq_len = train_data.element_spec[0].shape[1]
    char_len = train_data.element_spec[0].shape[2]
    
    tk = hdfslogs.tk    
    vocab_size = len(tk.word_index)
    print(f'vocab_size: {vocab_size}')
    char_onehot = vocab_size
    
    embedding_weights = []
    embedding_weights.append(np.zeros(vocab_size))
    for char, i in tk.word_index.items(): # from 1 to 51
        onehot = np.zeros(vocab_size)
        onehot[i-1] = 1
        embedding_weights.append(onehot)
    embedding_weights = np.array(embedding_weights)
    
    
    
    input_size = [seq_len, char_len]
    embedding_size = vocab_size

    embedding_layer = tf.keras.layers.Embedding(vocab_size+1,
                                                embedding_size,
                                                input_length=input_size,
                                                weights = [embedding_weights])
    
    
    
    
    inputs = tf.keras.layers.Input(batch_shape=(B, seq_len, char_len), dtype='float64' )
    x = tf.keras.layers.Embedding(input_dim=vocab_size+1,
                                    output_dim=embedding_size,
                                    input_length=char_len,
                                    weights = [embedding_weights],
                                    )(inputs)
    for _ in range(conv1d_set1):
        x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    if maxpool_1:
        x = tf.keras.layers.MaxPooling2D(pool_size=(1, char_len))(x)
        x = tf.reshape(x, (B, seq_len, filters))        
        for _ in range(conv1d_set2):
            x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
        x = tf.keras.layers.MaxPooling1D(pool_size=(seq_len) )(x)    
    if not maxpool_1:
        x = tf.keras.layers.Flatten()(x)       
    x = tf.keras.layers.Dense(dense_neurons)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    outputs = tf.reshape(outputs, (B, 1))
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    print(model.summary())
    model.compile(optimizer='adam', 
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
    hist = model.fit(train_data, validation_data=test_data, epochs=epochs) 
    return model, hist

# %%
test_model(ablation=10000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_176_time_ip.pkl')
# Out:
# train_hdfs_anomaly:, 8000, val_hdfs_anomaly:, 1000, test_hdfs_anomaly:, 1000, train_hdfs_normal:, 8000, val_hdfs_normal:, 1000, test_hdfs_normal:, 1000, train: hdfs_anomaly    8000
# hdfs_normal     8000
# Name: label, dtype: int64
# val: hdfs_anomaly    1000
# hdfs_normal     1000
# Name: label, dtype: int64
# test: hdfs_anomaly    1000
# hdfs_normal     1000
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 176
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 62
# length of train_data - (num_seq_per_cls * num_class)// batch size: 500
# <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(32, 32, 176)]           0
#
#  embedding_1 (Embedding)     (32, 32, 176, 42)         1806
#
#  conv1d (Conv1D)             (32, 32, 176, 64)         8128
#
#  conv1d_1 (Conv1D)           (32, 32, 176, 64)         12352
#
#  conv1d_2 (Conv1D)           (32, 32, 176, 64)         12352
#
#  max_pooling2d (MaxPooling2D  (32, 32, 1, 64)          0
#  )
#
#  tf.reshape (TFOpLambda)     (32, 32, 64)              0
#
#  conv1d_3 (Conv1D)           (32, 32, 64)              12352
#
#  conv1d_4 (Conv1D)           (32, 32, 64)              12352
#
#  conv1d_5 (Conv1D)           (32, 32, 64)              12352
#
#  max_pooling1d (MaxPooling1D  (32, 1, 64)              0
#  )
#
#  dense (Dense)               (32, 1, 2048)             133120
#
#  dense_1 (Dense)             (32, 1, 1)                2049
#
#  tf.reshape_1 (TFOpLambda)   (32, 1)                   0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 500/500 [==============================] - 115s 230ms/step - loss: 0.7591 - accuracy: 0.4994 - val_loss: 0.8143 - val_accuracy: 0.4990
# Epoch 2/16
# 500/500 [==============================] - 115s 229ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 3/16
# 500/500 [==============================] - 116s 233ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8123 - val_accuracy: 0.5010
# Epoch 4/16
# 500/500 [==============================] - 118s 236ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8128 - val_accuracy: 0.5005
# Epoch 5/16
# 500/500 [==============================] - 119s 237ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8128 - val_accuracy: 0.5005
# Epoch 6/16
# 500/500 [==============================] - 117s 235ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8138 - val_accuracy: 0.4995
# Epoch 7/16
# 500/500 [==============================] - 117s 234ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8123 - val_accuracy: 0.5010
# Epoch 8/16
# 500/500 [==============================] - 118s 237ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8117 - val_accuracy: 0.5015
# Epoch 9/16
# 500/500 [==============================] - 116s 233ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8112 - val_accuracy: 0.5020
# Epoch 10/16
# 407/500 [=======================>......] - ETA: 21s - loss: 0.8138 - accuracy: 0.4995

# %%
### going back to same setting as exp5

hlog_meta_64_256_no_meta = HDFSLogv3( debug=True )
res_64_256_no_meta = hlog_meta_64_256_no_meta.get_tensor_train_val_test(padded_seq_len=64, padded_char_len=256, 
                                                                        hdfs_rm_time_stamp=True, hdfs_rm_ip_address=True, 
                                                                        train_ratio=0.8, )
hlog_meta_64_256_no_meta.save_hdfs_log_obj()
### checking with a lower dataset
test_model(ablation=1000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl')
# Out:
# total number of lines in the log file: 11175629
# RAM usage:  100232088
# loaded logs in memory in time: 5.029593229293823
# loaded cleaned logs with blk_id  in memory: 88.31090927124023
# RAM usage:  100232088
# loaded cleaned logs without blkid in memory: 0.5669658184051514
# RAM usage:  100232088
# starting training the tokenizer:
# ending tokenizer training: 64.23376607894897
# RAM usage:  48
# vocabulary size: 42
# starting text to number conversion
# completed:  0
# time : 0.0010180473327636719
# completed:  1000000
# time : 12.662117958068848
# completed:  2000000
# time : 24.251131057739258
# completed:  3000000
# time : 37.0912082195282
# completed:  4000000
# time : 49.49365592002869
# completed:  5000000
# time : 61.82384181022644
# completed:  6000000
# time : 74.26996159553528
# completed:  7000000
# time : 87.01436758041382
# completed:  8000000
# time : 99.84939408302307
# completed:  9000000
# time : 112.75847816467285
# completed:  10000000
# time : 125.596120595932
# completed:  11000000
# time : 138.3616623878479
# ending text to number conversion: 140.70344352722168
# RAM usage:  100232088
# ending num_sequence_by_blkid conversion: 15.972422361373901
# RAM usage:  20971608
# ending labelled_num_seq_df conversion: 22.01779079437256
# RAM usage:  117329426
# len of pos_df 16838
# len of neg_df 558223
# eq_neg_pos_df shape: (33676, 2)
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 6
# length of train_data - (num_seq_per_cls * num_class)// batch size: 50
# saved hdfs object as data\hdfsobj_64_256_no_meta.pkl
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 9>()
#       7 hlog_meta_64_256_no_meta.save_hdfs_log_obj()
#       8 ### checking with a lower dataset
# ----> 9 test_model(ablation=1000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
#      10           hdfs_obJ_full_name='data\\hdfsobj_64_256_time_ip.pkl')
#
# Input In [2], in test_model(ablation, B, epochs, filters, kernel_size, dense_neurons, conv1d_set1, conv1d_set2, maxpool_1, hdfs_obJ_full_name)
#       6 tf.random.set_seed(123)
#       7 import pickle
# ----> 8 with open(hdfs_obJ_full_name, 'rb') as f:
#       9     hdfslogs = pickle.load(f)
#      10 # x_train, y_train, x_val, y_val, x_test, y_test
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\hdfsobj_64_256_time_ip.pkl'

# %%
test_model(ablation=1000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl')
# Out:
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 6
# length of train_data - (num_seq_per_cls * num_class)// batch size: 50
# <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(32, 64, 256)]           0
#
#  embedding_1 (Embedding)     (32, 64, 256, 42)         1806
#
#  conv1d (Conv1D)             (32, 64, 256, 64)         8128
#
#  conv1d_1 (Conv1D)           (32, 64, 256, 64)         12352
#
#  conv1d_2 (Conv1D)           (32, 64, 256, 64)         12352
#
#  max_pooling2d (MaxPooling2D  (32, 64, 1, 64)          0
#  )
#
#  tf.reshape (TFOpLambda)     (32, 64, 64)              0
#
#  conv1d_3 (Conv1D)           (32, 64, 64)              12352
#
#  conv1d_4 (Conv1D)           (32, 64, 64)              12352
#
#  conv1d_5 (Conv1D)           (32, 64, 64)              12352
#
#  max_pooling1d (MaxPooling1D  (32, 1, 64)              0
#  )
#
#  dense (Dense)               (32, 1, 2048)             133120
#
#  dense_1 (Dense)             (32, 1, 1)                2049
#
#  tf.reshape_1 (TFOpLambda)   (32, 1)                   0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 50/50 [==============================] - 35s 694ms/step - loss: 0.6210 - accuracy: 0.6950 - val_loss: 0.6061 - val_accuracy: 0.7240
# Epoch 2/16
# 50/50 [==============================] - 35s 693ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6058 - val_accuracy: 0.7135
# Epoch 3/16
# 50/50 [==============================] - 34s 688ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6077 - val_accuracy: 0.7292
# Epoch 4/16
# 50/50 [==============================] - 34s 685ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6057 - val_accuracy: 0.7188
# Epoch 5/16
# 50/50 [==============================] - 34s 687ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6056 - val_accuracy: 0.7344
# Epoch 6/16
# 50/50 [==============================] - 35s 701ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6036 - val_accuracy: 0.7240
# Epoch 7/16
# 50/50 [==============================] - 36s 712ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6055 - val_accuracy: 0.7188
# Epoch 8/16
# 50/50 [==============================] - 34s 689ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6074 - val_accuracy: 0.7292
# Epoch 9/16
# 50/50 [==============================] - 35s 692ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6073 - val_accuracy: 0.7240
# Epoch 10/16
# 50/50 [==============================] - 35s 696ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6053 - val_accuracy: 0.7292
# Epoch 11/16
# 50/50 [==============================] - 35s 708ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6052 - val_accuracy: 0.7292
# Epoch 12/16
# 50/50 [==============================] - 35s 698ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6091 - val_accuracy: 0.7188
# Epoch 13/16
# 50/50 [==============================] - 35s 704ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6071 - val_accuracy: 0.7188
# Epoch 14/16
# 50/50 [==============================] - 35s 706ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6090 - val_accuracy: 0.7188
# Epoch 15/16
# 50/50 [==============================] - 35s 710ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6050 - val_accuracy: 0.7188
# Epoch 16/16
# 50/50 [==============================] - 35s 701ms/step - loss: 0.5963 - accuracy: 0.7550 - val_loss: 0.6070 - val_accuracy: 0.7188
# (<keras.engine.functional.Functional at 0x268e27e8af0>,
#  <keras.callbacks.History at 0x268e2d81af0>)

# %%
# earlier 4000 train data and 4000 test data 
### now 5000 x 0.8 = 4000 train data and 500 val , 500 test
## That way the training accuracy should be same , val accuracy should be better
test_model(ablation=5000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl')
# Out:
# train_hdfs_anomaly:, 4000, val_hdfs_anomaly:, 500, test_hdfs_anomaly:, 500, train_hdfs_normal:, 4000, val_hdfs_normal:, 500, test_hdfs_normal:, 500, train: hdfs_anomaly    4000
# hdfs_normal     4000
# Name: label, dtype: int64
# val: hdfs_anomaly    500
# hdfs_normal     500
# Name: label, dtype: int64
# test: hdfs_anomaly    500
# hdfs_normal     500
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 31
# length of train_data - (num_seq_per_cls * num_class)// batch size: 250
# <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(32, 64, 256)]           0
#
#  embedding_3 (Embedding)     (32, 64, 256, 42)         1806
#
#  conv1d_6 (Conv1D)           (32, 64, 256, 64)         8128
#
#  conv1d_7 (Conv1D)           (32, 64, 256, 64)         12352
#
#  conv1d_8 (Conv1D)           (32, 64, 256, 64)         12352
#
#  max_pooling2d_1 (MaxPooling  (32, 64, 1, 64)          0
#  2D)
#
#  tf.reshape_2 (TFOpLambda)   (32, 64, 64)              0
#
#  conv1d_9 (Conv1D)           (32, 64, 64)              12352
#
#  conv1d_10 (Conv1D)          (32, 64, 64)              12352
#
#  conv1d_11 (Conv1D)          (32, 64, 64)              12352
#
#  max_pooling1d_1 (MaxPooling  (32, 1, 64)              0
#  1D)
#
#  dense_2 (Dense)             (32, 1, 2048)             133120
#
#  dense_3 (Dense)             (32, 1, 1)                2049
#
#  tf.reshape_3 (TFOpLambda)   (32, 1)                   0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 250/250 [==============================] - 173s 689ms/step - loss: 0.6859 - accuracy: 0.6376 - val_loss: 0.8153 - val_accuracy: 0.4980
# Epoch 2/16
# 250/250 [==============================] - 174s 696ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 3/16
# 250/250 [==============================] - 175s 701ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 4/16
# 250/250 [==============================] - 174s 697ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 5/16
# 250/250 [==============================] - 175s 701ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 6/16
# 250/250 [==============================] - 173s 691ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 7/16
# 250/250 [==============================] - 174s 698ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8123 - val_accuracy: 0.5010
# Epoch 8/16
# 250/250 [==============================] - 173s 692ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8163 - val_accuracy: 0.4970
# Epoch 9/16
# 250/250 [==============================] - 171s 683ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 10/16
# 250/250 [==============================] - 171s 682ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8143 - val_accuracy: 0.4990
# Epoch 11/16
# 250/250 [==============================] - 171s 683ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8163 - val_accuracy: 0.4970
# Epoch 12/16
# 250/250 [==============================] - 171s 683ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8143 - val_accuracy: 0.4990
# Epoch 13/16
# 250/250 [==============================] - 170s 679ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 14/16
# 250/250 [==============================] - 170s 680ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8112 - val_accuracy: 0.5020
# Epoch 15/16
# 250/250 [==============================] - 170s 681ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 16/16
# 250/250 [==============================] - 172s 690ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8123 - val_accuracy: 0.5010
# (<keras.engine.functional.Functional at 0x268e0b9bbb0>,
#  <keras.callbacks.History at 0x268e0b945e0>)

# %%
hlog_meta_32_256_no_meta = HDFSLogv3( debug=True )
res_32_256_no_meta = hlog_meta_32_256_no_meta.get_tensor_train_val_test(padded_seq_len=32, padded_char_len=256, 
                                                                        hdfs_rm_time_stamp=True, hdfs_rm_ip_address=True, 
                                                                        train_ratio=0.8, )
hlog_meta_32_256_no_meta.save_hdfs_log_obj()
### checking with a lower dataset
test_model(ablation=4000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_256_no_meta.pkl')
# Out:
# total number of lines in the log file: 11175629
# RAM usage:  100232088
# loaded logs in memory in time: 4.933324337005615
# loaded cleaned logs with blk_id  in memory: 85.37875890731812
# RAM usage:  100232088
# loaded cleaned logs without blkid in memory: 0.5400216579437256
# RAM usage:  100232088
# starting training the tokenizer:
# ending tokenizer training: 69.99258422851562
# RAM usage:  48
# vocabulary size: 42
# starting text to number conversion
# completed:  0
# time : 0.0010149478912353516
# completed:  1000000
# time : 12.627539873123169
# completed:  2000000
# time : 24.247183799743652
# completed:  3000000
# time : 37.220115661621094
# completed:  4000000
# time : 49.73269605636597
# completed:  5000000
# time : 62.300745725631714
# completed:  6000000
# time : 74.95747375488281
# completed:  7000000
# time : 87.89728498458862
# completed:  8000000
# time : 100.81793713569641
# completed:  9000000
# time : 113.7482979297638
# completed:  10000000
# time : 126.63212776184082
# completed:  11000000
# time : 139.6336259841919
# ending text to number conversion: 142.03648138046265
# RAM usage:  100232088
# ending num_sequence_by_blkid conversion: 14.84914493560791
# RAM usage:  20971608
# ending labelled_num_seq_df conversion: 16.496092081069946
# RAM usage:  117329426
# len of pos_df 16838
# len of neg_df 558223
# eq_neg_pos_df shape: (33676, 2)
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 6
# length of train_data - (num_seq_per_cls * num_class)// batch size: 50
# saved hdfs object as data\hdfsobj_32_256_no_meta.pkl
# train_hdfs_anomaly:, 3200, val_hdfs_anomaly:, 400, test_hdfs_anomaly:, 400, train_hdfs_normal:, 3200, val_hdfs_normal:, 400, test_hdfs_normal:, 400, train: hdfs_anomaly    3200
# hdfs_normal     3200
# Name: label, dtype: int64
# val: hdfs_anomaly    400
# hdfs_normal     400
# Name: label, dtype: int64
# test: hdfs_anomaly    400
# hdfs_normal     400
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 25
# length of train_data - (num_seq_per_cls * num_class)// batch size: 200
# <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(32, 32, 256)]           0
#
#  embedding_5 (Embedding)     (32, 32, 256, 42)         1806
#
#  conv1d_12 (Conv1D)          (32, 32, 256, 64)         8128
#
#  conv1d_13 (Conv1D)          (32, 32, 256, 64)         12352
#
#  conv1d_14 (Conv1D)          (32, 32, 256, 64)         12352
#
#  max_pooling2d_2 (MaxPooling  (32, 32, 1, 64)          0
#  2D)
#
#  tf.reshape_4 (TFOpLambda)   (32, 32, 64)              0
#
#  conv1d_15 (Conv1D)          (32, 32, 64)              12352
#
#  conv1d_16 (Conv1D)          (32, 32, 64)              12352
#
#  conv1d_17 (Conv1D)          (32, 32, 64)              12352
#
#  max_pooling1d_2 (MaxPooling  (32, 1, 64)              0
#  1D)
#
#  dense_4 (Dense)             (32, 1, 2048)             133120
#
#  dense_5 (Dense)             (32, 1, 1)                2049
#
#  tf.reshape_5 (TFOpLambda)   (32, 1)                   0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 200/200 [==============================] - 68s 335ms/step - loss: 0.5945 - accuracy: 0.7659 - val_loss: 0.5785 - val_accuracy: 0.8050
# Epoch 2/16
# 200/200 [==============================] - 67s 337ms/step - loss: 0.5926 - accuracy: 0.7684 - val_loss: 0.5972 - val_accuracy: 0.7525
# Epoch 3/16
# 200/200 [==============================] - 68s 341ms/step - loss: 0.5993 - accuracy: 0.7484 - val_loss: 0.5852 - val_accuracy: 0.8112
# Epoch 4/16
# 200/200 [==============================] - 68s 338ms/step - loss: 0.6001 - accuracy: 0.7459 - val_loss: 0.5972 - val_accuracy: 0.7525
# Epoch 5/16
# 200/200 [==============================] - 68s 338ms/step - loss: 0.5972 - accuracy: 0.7542 - val_loss: 0.5978 - val_accuracy: 0.7513
# Epoch 6/16
# 200/200 [==============================] - 68s 341ms/step - loss: 0.6937 - accuracy: 0.6419 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 7/16
# 200/200 [==============================] - 69s 346ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 8/16
# 200/200 [==============================] - 68s 340ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 9/16
# 200/200 [==============================] - 68s 340ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 10/16
# 200/200 [==============================] - 68s 340ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 11/16
# 200/200 [==============================] - 68s 342ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 12/16
# 200/200 [==============================] - 69s 344ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 13/16
# 200/200 [==============================] - 68s 339ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 14/16
# 200/200 [==============================] - 68s 340ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 15/16
# 200/200 [==============================] - 68s 340ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# Epoch 16/16
# 200/200 [==============================] - 68s 338ms/step - loss: 0.8133 - accuracy: 0.5000 - val_loss: 0.8133 - val_accuracy: 0.5000
# (<keras.engine.functional.Functional at 0x271cdf9cd60>,
#  <keras.callbacks.History at 0x268e0ba0700>)

# %%
hlog_meta_32_256_time_ip = HDFSLogv3( debug=True )
res_32_256_time_ip = hlog_meta_32_256_time_ip.get_tensor_train_val_test(padded_seq_len=32, padded_char_len=256, 
                                                                        hdfs_rm_time_stamp=False, hdfs_rm_ip_address=False, 
                                                                        train_ratio=0.8, )
hlog_meta_32_256_time_ip.save_hdfs_log_obj()
### checking with a lower dataset
test_model(ablation=4000, B=32, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_256_time_ip.pkl')
# Out:
# total number of lines in the log file: 11175629
# RAM usage:  100232088
# loaded logs in memory in time: 5.099388360977173
# loaded cleaned logs with blk_id  in memory: 202.86901998519897
# RAM usage:  100232088
# loaded cleaned logs without blkid in memory: 0.5159964561462402
# RAM usage:  100232088
# starting training the tokenizer:
# ending tokenizer training: 104.92351031303406
# RAM usage:  48
# vocabulary size: 42
# starting text to number conversion
# completed:  0
# time : 0.0009996891021728516
# completed:  1000000
# time : 16.80386734008789
# completed:  2000000
# time : 32.978227615356445
# completed:  3000000
# time : 49.299583435058594
# completed:  4000000
# time : 66.06988310813904
# completed:  5000000
# time : 82.42038655281067
# completed:  6000000
# time : 99.1083152294159
# completed:  7000000
# time : 115.91031098365784
# completed:  8000000
# time : 132.6258533000946
# completed:  9000000
# time : 149.34427404403687
# completed:  10000000
# time : 165.959894657135
# completed:  11000000
# time : 182.95886516571045
# ending text to number conversion: 185.80508637428284
# RAM usage:  100232088
# ending num_sequence_by_blkid conversion: 14.777554750442505
# RAM usage:  20971608
# ending labelled_num_seq_df conversion: 16.87200665473938
# RAM usage:  117329426
# len of pos_df 16838
# len of neg_df 558223
# eq_neg_pos_df shape: (33676, 2)
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 6
# length of train_data - (num_seq_per_cls * num_class)// batch size: 50
# saved hdfs object as data\hdfsobj_32_256_time_ip.pkl
# train_hdfs_anomaly:, 3200, val_hdfs_anomaly:, 400, test_hdfs_anomaly:, 400, train_hdfs_normal:, 3200, val_hdfs_normal:, 400, test_hdfs_normal:, 400, train: hdfs_anomaly    3200
# hdfs_normal     3200
# Name: label, dtype: int64
# val: hdfs_anomaly    400
# hdfs_normal     400
# Name: label, dtype: int64
# test: hdfs_anomaly    400
# hdfs_normal     400
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 25
# length of train_data - (num_seq_per_cls * num_class)// batch size: 200
# <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(32, 32, 256)]           0
#
#  embedding_7 (Embedding)     (32, 32, 256, 42)         1806
#
#  conv1d_18 (Conv1D)          (32, 32, 256, 64)         8128
#
#  conv1d_19 (Conv1D)          (32, 32, 256, 64)         12352
#
#  conv1d_20 (Conv1D)          (32, 32, 256, 64)         12352
#
#  max_pooling2d_3 (MaxPooling  (32, 32, 1, 64)          0
#  2D)
#
#  tf.reshape_6 (TFOpLambda)   (32, 32, 64)              0
#
#  conv1d_21 (Conv1D)          (32, 32, 64)              12352
#
#  conv1d_22 (Conv1D)          (32, 32, 64)              12352
#
#  conv1d_23 (Conv1D)          (32, 32, 64)              12352
#
#  max_pooling1d_3 (MaxPooling  (32, 1, 64)              0
#  1D)
#
#  dense_6 (Dense)             (32, 1, 2048)             133120
#
#  dense_7 (Dense)             (32, 1, 1)                2049
#
#  tf.reshape_7 (TFOpLambda)   (32, 1)                   0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 200/200 [==============================] - 67s 335ms/step - loss: 0.5914 - accuracy: 0.7811 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 2/16
# 200/200 [==============================] - 68s 338ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 3/16
# 200/200 [==============================] - 68s 338ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 4/16
# 200/200 [==============================] - 68s 339ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 5/16
# 200/200 [==============================] - 71s 353ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 6/16
# 200/200 [==============================] - 71s 354ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 7/16
# 200/200 [==============================] - 68s 341ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 8/16
# 200/200 [==============================] - 70s 349ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 9/16
# 200/200 [==============================] - 69s 345ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 10/16
# 200/200 [==============================] - 70s 349ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 11/16
# 200/200 [==============================] - 71s 354ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 12/16
# 200/200 [==============================] - 70s 351ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 13/16
# 200/200 [==============================] - 70s 351ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 14/16
# 200/200 [==============================] - 70s 349ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 15/16
# 200/200 [==============================] - 68s 342ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# Epoch 16/16
# 200/200 [==============================] - 69s 344ms/step - loss: 0.5790 - accuracy: 0.8134 - val_loss: 0.5759 - val_accuracy: 0.8213
# (<keras.engine.functional.Functional at 0x271d56be5e0>,
#  <keras.callbacks.History at 0x271ce5fc490>)

# %%
### increasing batch_size same as exp5
test_model(ablation=5000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl')
# Out:
# train_hdfs_anomaly:, 4000, val_hdfs_anomaly:, 500, test_hdfs_anomaly:, 500, train_hdfs_normal:, 4000, val_hdfs_normal:, 500, test_hdfs_normal:, 500, train: hdfs_anomaly    4000
# hdfs_normal     4000
# Name: label, dtype: int64
# val: hdfs_anomaly    500
# hdfs_normal     500
# Name: label, dtype: int64
# test: hdfs_anomaly    500
# hdfs_normal     500
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 3
# length of train_data - (num_seq_per_cls * num_class)// batch size: 31
# <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(256, 64, 256)]          0
#
#  embedding_1 (Embedding)     (256, 64, 256, 42)        1806
#
#  conv1d (Conv1D)             (256, 64, 256, 64)        8128
#
#  conv1d_1 (Conv1D)           (256, 64, 256, 64)        12352
#
#  conv1d_2 (Conv1D)           (256, 64, 256, 64)        12352
#
#  max_pooling2d (MaxPooling2D  (256, 64, 1, 64)         0
#  )
#
#  tf.reshape (TFOpLambda)     (256, 64, 64)             0
#
#  conv1d_3 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_4 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_5 (Conv1D)           (256, 64, 64)             12352
#
#  max_pooling1d (MaxPooling1D  (256, 1, 64)             0
#  )
#
#  dense (Dense)               (256, 1, 2048)            133120
#
#  dense_1 (Dense)             (256, 1, 1)               2049
#
#  tf.reshape_1 (TFOpLambda)   (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 31/31 [==============================] - 168s 5s/step - loss: 0.6274 - accuracy: 0.6787 - val_loss: 0.5976 - val_accuracy: 0.7721
# Epoch 2/16
# 31/31 [==============================] - 165s 5s/step - loss: 0.5961 - accuracy: 0.7645 - val_loss: 0.5970 - val_accuracy: 0.7617
# Epoch 3/16
# 31/31 [==============================] - 165s 5s/step - loss: 0.5963 - accuracy: 0.7586 - val_loss: 0.5946 - val_accuracy: 0.7630
# Epoch 4/16
# 31/31 [==============================] - 163s 5s/step - loss: 0.5959 - accuracy: 0.7589 - val_loss: 0.5964 - val_accuracy: 0.7799
# Epoch 5/16
# 31/31 [==============================] - 169s 5s/step - loss: 0.6042 - accuracy: 0.7418 - val_loss: 0.5907 - val_accuracy: 0.7669
# Epoch 6/16
# 31/31 [==============================] - 170s 5s/step - loss: 0.5962 - accuracy: 0.7671 - val_loss: 0.5862 - val_accuracy: 0.7786
# Epoch 7/16
# 31/31 [==============================] - 172s 6s/step - loss: 0.5981 - accuracy: 0.7666 - val_loss: 0.5891 - val_accuracy: 0.7826
# Epoch 8/16
# 31/31 [==============================] - 174s 6s/step - loss: 0.5954 - accuracy: 0.7660 - val_loss: 0.5968 - val_accuracy: 0.7721
# Epoch 9/16
# 31/31 [==============================] - 173s 6s/step - loss: 0.5952 - accuracy: 0.7605 - val_loss: 0.5935 - val_accuracy: 0.7682
# Epoch 10/16
# 31/31 [==============================] - 171s 6s/step - loss: 0.5975 - accuracy: 0.7647 - val_loss: 0.5927 - val_accuracy: 0.7812
# Epoch 11/16
# 31/31 [==============================] - 170s 5s/step - loss: 0.5961 - accuracy: 0.7600 - val_loss: 0.5960 - val_accuracy: 0.7630
# Epoch 12/16
# 31/31 [==============================] - 176s 6s/step - loss: 0.5949 - accuracy: 0.7625 - val_loss: 0.5921 - val_accuracy: 0.7552
# Epoch 13/16
# 31/31 [==============================] - 172s 6s/step - loss: 0.5951 - accuracy: 0.7625 - val_loss: 0.5949 - val_accuracy: 0.7630
# Epoch 14/16
# 28/31 [==========================>...] - ETA: 16s - loss: 0.6008 - accuracy: 0.7631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 ### increasing batch_size same as exp5
# ----> 2 test_model(ablation=5000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
#       3           hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl')
#
# Input In [2], in test_model(ablation, batch_size, epochs, filters, kernel_size, dense_neurons, conv1d_set1, conv1d_set2, maxpool_1, hdfs_obJ_full_name)
#      64 print(model.summary())
#      65 model.compile(optimizer='adam',
#      66               loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
#      67           metrics=['accuracy'])
# ---> 68 hist = model.fit(train_data, validation_data=test_data, epochs=epochs)
#      69 return model, hist
#
# File ~\venv1\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\venv1\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~\venv1\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\venv1\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\venv1\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\venv1\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\venv1\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\venv1\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\venv1\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# we can check 64_256 with 4000 train and 4000 test
