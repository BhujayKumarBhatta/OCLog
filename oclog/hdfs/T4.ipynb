# %%
import random
# from hdflogv2 import HDFSLogv2
from hdflogv3 import HDFSLogv3
import tensorflow as tf
import numpy as np
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
import pickle
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
tf.random.set_seed(123)
np.random.seed(123)

# %%
def test_model(ablation=1000, batch_size=32, epochs=3, filters=64, kernel_size=3, dense_neurons=2048, 
              conv1d_set1=1, conv1d_set2=1, maxpool_1=False, hdfs_obJ_full_name=None, 
               train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    # from hdflogv2 import HDFSLogv2
    import tensorflow as tf
    import numpy as np
    tf.random.set_seed(123)
    import pickle
    with open(hdfs_obJ_full_name, 'rb') as f:
        hdfslogs = pickle.load(f)    
    # x_train, y_train, x_val, y_val, x_test, y_test 
    train_data, val_data, test_data = hdfslogs.get_tensor_train_val_test(ablation=ablation, batch_size=batch_size, 
                                                                         train_ratio=train_ratio, 
                                                                         val_ratio=val_ratio, 
                                                                         test_ratio=test_ratio)    
    print(train_data)
    B = batch_size
    # B = train_data.element_spec[0].shape[0]
    seq_len = train_data.element_spec[0].shape[1]
    char_len = train_data.element_spec[0].shape[2]
    
    tk = hdfslogs.tk    
    vocab_size = len(tk.word_index)
    print(f'vocab_size: {vocab_size}')
    char_onehot = vocab_size
    
    embedding_weights = []
    embedding_weights.append(np.zeros(vocab_size))
    for char, i in tk.word_index.items(): # from 1 to 51
        onehot = np.zeros(vocab_size)
        onehot[i-1] = 1
        embedding_weights.append(onehot)
    embedding_weights = np.array(embedding_weights)
    
    
    
    input_size = [seq_len, char_len]
    embedding_size = vocab_size

    embedding_layer = tf.keras.layers.Embedding(vocab_size+1,
                                                embedding_size,
                                                input_length=input_size,
                                                weights = [embedding_weights])
    
    
    
    
    inputs = tf.keras.layers.Input(batch_shape=(B, seq_len, char_len), dtype='float64' )
    x = tf.keras.layers.Embedding(input_dim=vocab_size+1,
                                    output_dim=embedding_size,
                                    input_length=char_len,
                                    weights = [embedding_weights],
                                    )(inputs)
    for _ in range(conv1d_set1):
        x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    if maxpool_1:
        x = tf.keras.layers.MaxPooling2D(pool_size=(1, char_len))(x)
        x = tf.reshape(x, (B, seq_len, filters))        
        for _ in range(conv1d_set2):
            x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
        x = tf.keras.layers.MaxPooling1D(pool_size=(seq_len) )(x)    
    if not maxpool_1:
        x = tf.keras.layers.Flatten()(x)       
    x = tf.keras.layers.Dense(dense_neurons)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    outputs = tf.reshape(outputs, (B, 1))
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    print(model.summary())
    model.compile(optimizer='adam', 
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
    ################# Early Stopiing #####################
    monitor_metric = 'val_accuracy'
    LR = ReduceLROnPlateau(monitor=monitor_metric, factor=0.5, patience=2, cooldown=1, verbose=1)
    earlystop = EarlyStopping(monitor=monitor_metric, min_delta=0, patience=3, verbose=1)
    callbacks_list = [ LR, earlystop] 
    hist = model.fit(train_data, validation_data=test_data, epochs=epochs, callbacks=callbacks_list) 
    return model, hist

# %%
### early stop
test_model(ablation=5000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl')
# Out:
# train_hdfs_anomaly:, 4000, val_hdfs_anomaly:, 500, test_hdfs_anomaly:, 500, train_hdfs_normal:, 4000, val_hdfs_normal:, 500, test_hdfs_normal:, 500, train: hdfs_anomaly    4000
# hdfs_normal     4000
# Name: label, dtype: int64
# val: hdfs_anomaly    500
# hdfs_normal     500
# Name: label, dtype: int64
# test: hdfs_anomaly    500
# hdfs_normal     500
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 3
# length of train_data - (num_seq_per_cls * num_class)// batch size: 31
# <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(256, 64, 256)]          0
#
#  embedding_1 (Embedding)     (256, 64, 256, 42)        1806
#
#  conv1d (Conv1D)             (256, 64, 256, 64)        8128
#
#  conv1d_1 (Conv1D)           (256, 64, 256, 64)        12352
#
#  conv1d_2 (Conv1D)           (256, 64, 256, 64)        12352
#
#  max_pooling2d (MaxPooling2D  (256, 64, 1, 64)         0
#  )
#
#  tf.reshape (TFOpLambda)     (256, 64, 64)             0
#
#  conv1d_3 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_4 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_5 (Conv1D)           (256, 64, 64)             12352
#
#  max_pooling1d (MaxPooling1D  (256, 1, 64)             0
#  )
#
#  dense (Dense)               (256, 1, 2048)            133120
#
#  dense_1 (Dense)             (256, 1, 1)               2049
#
#  tf.reshape_1 (TFOpLambda)   (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 31/31 [==============================] - 169s 5s/step - loss: 0.6274 - accuracy: 0.6787 - val_loss: 0.5976 - val_accuracy: 0.7721 - lr: 0.0010
# Epoch 2/16
# 31/31 [==============================] - 167s 5s/step - loss: 0.5961 - accuracy: 0.7645 - val_loss: 0.5970 - val_accuracy: 0.7617 - lr: 0.0010
# Epoch 3/16
# 31/31 [==============================] - ETA: 0s - loss: 0.5963 - accuracy: 0.7586
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 31/31 [==============================] - 169s 5s/step - loss: 0.5963 - accuracy: 0.7586 - val_loss: 0.5946 - val_accuracy: 0.7630 - lr: 0.0010
# Epoch 4/16
# 31/31 [==============================] - 169s 5s/step - loss: 0.5954 - accuracy: 0.7607 - val_loss: 0.6007 - val_accuracy: 0.7617 - lr: 5.0000e-04
# Epoch 4: early stopping
# (<keras.engine.functional.Functional at 0x1cb92595a30>,
#  <keras.callbacks.History at 0x1cb925bd850>)

# %%
# we can check 64_256 with 4000 train and 4000 test
test_model(ablation=12000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_no_meta.pkl', train_ratio=0.35, val_ratio=0.35, test_ratio=0.30)
# Out:
# train_hdfs_anomaly:, 4200, val_hdfs_anomaly:, 4200, test_hdfs_anomaly:, 3600, train_hdfs_normal:, 4200, val_hdfs_normal:, 4200, test_hdfs_normal:, 3600, train: hdfs_anomaly    4200
# hdfs_normal     4200
# Name: label, dtype: int64
# val: hdfs_anomaly    4200
# hdfs_normal     4200
# Name: label, dtype: int64
# test: hdfs_anomaly    3600
# hdfs_normal     3600
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 32
# length of train_data - (num_seq_per_cls * num_class)// batch size: 32
# <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(256, 64, 256)]          0
#
#  embedding_1 (Embedding)     (256, 64, 256, 42)        1806
#
#  conv1d (Conv1D)             (256, 64, 256, 64)        8128
#
#  conv1d_1 (Conv1D)           (256, 64, 256, 64)        12352
#
#  conv1d_2 (Conv1D)           (256, 64, 256, 64)        12352
#
#  max_pooling2d (MaxPooling2D  (256, 64, 1, 64)         0
#  )
#
#  tf.reshape (TFOpLambda)     (256, 64, 64)             0
#
#  conv1d_3 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_4 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_5 (Conv1D)           (256, 64, 64)             12352
#
#  max_pooling1d (MaxPooling1D  (256, 1, 64)             0
#  )
#
#  dense (Dense)               (256, 1, 2048)            133120
#
#  dense_1 (Dense)             (256, 1, 1)               2049
#
#  tf.reshape_1 (TFOpLambda)   (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 32/32 [==============================] - 205s 6s/step - loss: 0.6257 - accuracy: 0.6877 - val_loss: 0.6255 - val_accuracy: 0.6961 - lr: 0.0010
# Epoch 2/16
# 32/32 [==============================] - 202s 6s/step - loss: 0.5954 - accuracy: 0.7643 - val_loss: 0.6201 - val_accuracy: 0.6918 - lr: 0.0010
# Epoch 3/16
# 32/32 [==============================] - ETA: 0s - loss: 0.5932 - accuracy: 0.7679
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 [==============================] - 203s 6s/step - loss: 0.5932 - accuracy: 0.7679 - val_loss: 0.6200 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 4/16
# 32/32 [==============================] - 201s 6s/step - loss: 0.5917 - accuracy: 0.7704 - val_loss: 0.6169 - val_accuracy: 0.7058 - lr: 5.0000e-04
# Epoch 5/16
# 32/32 [==============================] - 202s 6s/step - loss: 0.5927 - accuracy: 0.7678 - val_loss: 0.6220 - val_accuracy: 0.7013 - lr: 5.0000e-04
# Epoch 6/16
# 32/32 [==============================] - ETA: 0s - loss: 0.5995 - accuracy: 0.7512
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 [==============================] - 204s 6s/step - loss: 0.5995 - accuracy: 0.7512 - val_loss: 0.6251 - val_accuracy: 0.6791 - lr: 5.0000e-04
# Epoch 7/16
# 32/32 [==============================] - 204s 6s/step - loss: 0.5987 - accuracy: 0.7498 - val_loss: 0.6203 - val_accuracy: 0.6915 - lr: 2.5000e-04
# Epoch 7: early stopping
# (<keras.engine.functional.Functional at 0x18274f67ee0>,
#  <keras.callbacks.History at 0x181a867fb80>)

# %%
# we can check 64_256 with 4000 train and 4000 test
hlog_meta_64_256_time_ip = HDFSLogv3( debug=True )
res_64_256_time_ip = hlog_meta_64_256_time_ip.get_tensor_train_val_test(padded_seq_len=64, padded_char_len=256, 
                                                                        hdfs_rm_time_stamp=False, hdfs_rm_ip_address=False, 
                                                                        train_ratio=0.8, )
hlog_meta_64_256_time_ip.save_hdfs_log_obj()

test_model(ablation=12000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_64_256_time_ip.pkl', train_ratio=0.35, val_ratio=0.35, test_ratio=0.30)
# Out:
# total number of lines in the log file: 11175629
# RAM usage:  100232088
# loaded logs in memory in time: 4.986243724822998
# loaded cleaned logs with blk_id  in memory: 202.5606620311737
# RAM usage:  100232088
# loaded cleaned logs without blkid in memory: 0.6442639827728271
# RAM usage:  100232088
# starting training the tokenizer:
# ending tokenizer training: 109.69133853912354
# RAM usage:  48
# vocabulary size: 42
# starting text to number conversion
# completed:  0
# time : 0.0
# completed:  1000000
# time : 17.371644973754883
# completed:  2000000
# time : 34.09197378158569
# completed:  3000000
# time : 51.08361482620239
# completed:  4000000
# time : 68.5211124420166
# completed:  5000000
# time : 85.38474225997925
# completed:  6000000
# time : 102.4377372264862
# completed:  7000000
# time : 121.05865240097046
# completed:  8000000
# time : 138.07822132110596
# completed:  9000000
# time : 155.37119960784912
# completed:  10000000
# time : 173.60666227340698
# completed:  11000000
# time : 192.4757251739502
# ending text to number conversion: 195.74587297439575
# RAM usage:  100232088
# ending num_sequence_by_blkid conversion: 16.834033727645874
# RAM usage:  20971608
# ending labelled_num_seq_df conversion: 21.59986662864685
# RAM usage:  117329426
# len of pos_df 16838
# len of neg_df 558223
# eq_neg_pos_df shape: (33676, 2)
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(32,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (32,)
# length of val_data: 6
# length of train_data - (num_seq_per_cls * num_class)// batch size: 50
# saved hdfs object as data\hdfsobj_64_256_time_ip.pkl
# train_hdfs_anomaly:, 4200, val_hdfs_anomaly:, 4200, test_hdfs_anomaly:, 3600, train_hdfs_normal:, 4200, val_hdfs_normal:, 4200, test_hdfs_normal:, 3600, train: hdfs_anomaly    4200
# hdfs_normal     4200
# Name: label, dtype: int64
# val: hdfs_anomaly    4200
# hdfs_normal     4200
# Name: label, dtype: int64
# test: hdfs_anomaly    3600
# hdfs_normal     3600
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 256
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 32
# length of train_data - (num_seq_per_cls * num_class)// batch size: 32
# <BatchDataset element_spec=(TensorSpec(shape=(256, 64, 256), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(256, 64, 256)]          0
#
#  embedding_3 (Embedding)     (256, 64, 256, 42)        1806
#
#  conv1d_6 (Conv1D)           (256, 64, 256, 64)        8128
#
#  conv1d_7 (Conv1D)           (256, 64, 256, 64)        12352
#
#  conv1d_8 (Conv1D)           (256, 64, 256, 64)        12352
#
#  max_pooling2d_1 (MaxPooling  (256, 64, 1, 64)         0
#  2D)
#
#  tf.reshape_2 (TFOpLambda)   (256, 64, 64)             0
#
#  conv1d_9 (Conv1D)           (256, 64, 64)             12352
#
#  conv1d_10 (Conv1D)          (256, 64, 64)             12352
#
#  conv1d_11 (Conv1D)          (256, 64, 64)             12352
#
#  max_pooling1d_1 (MaxPooling  (256, 1, 64)             0
#  1D)
#
#  dense_2 (Dense)             (256, 1, 2048)            133120
#
#  dense_3 (Dense)             (256, 1, 1)               2049
#
#  tf.reshape_3 (TFOpLambda)   (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 32/32 [==============================] - 215s 7s/step - loss: 0.6315 - accuracy: 0.6692 - val_loss: 0.6252 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 2/16
# 32/32 [==============================] - 207s 7s/step - loss: 0.6003 - accuracy: 0.7448 - val_loss: 0.6253 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 3/16
# 32/32 [==============================] - 209s 7s/step - loss: 0.6001 - accuracy: 0.7452 - val_loss: 0.6251 - val_accuracy: 0.6789 - lr: 0.0010
# Epoch 4/16
# 32/32 [==============================] - 208s 7s/step - loss: 0.5998 - accuracy: 0.7444 - val_loss: 0.6250 - val_accuracy: 0.6791 - lr: 0.0010
# Epoch 5/16
# 32/32 [==============================] - 211s 7s/step - loss: 0.6008 - accuracy: 0.7443 - val_loss: 0.6252 - val_accuracy: 0.6794 - lr: 0.0010
# Epoch 6/16
# 32/32 [==============================] - 207s 6s/step - loss: 0.6001 - accuracy: 0.7445 - val_loss: 0.6249 - val_accuracy: 0.6795 - lr: 0.0010
# Epoch 7/16
# 32/32 [==============================] - 207s 7s/step - loss: 0.6003 - accuracy: 0.7457 - val_loss: 0.6251 - val_accuracy: 0.6790 - lr: 0.0010
# Epoch 8/16
# 32/32 [==============================] - ETA: 0s - loss: 0.6006 - accuracy: 0.7448
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 [==============================] - 206s 6s/step - loss: 0.6006 - accuracy: 0.7448 - val_loss: 0.6249 - val_accuracy: 0.6793 - lr: 0.0010
# Epoch 9/16
# 32/32 [==============================] - 209s 7s/step - loss: 0.6002 - accuracy: 0.7445 - val_loss: 0.6252 - val_accuracy: 0.6793 - lr: 5.0000e-04
# Epoch 9: early stopping
# (<keras.engine.functional.Functional at 0x18b619743a0>,
#  <keras.callbacks.History at 0x181fa63fd30>)

# %%
##### with 1 K data ##################
test_model(ablation=1000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_64_time_ip.pkl', train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)
# Out:
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 64
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 0
# length of train_data - (num_seq_per_cls * num_class)// batch size: 6
# <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(256, 32, 64)]           0
#
#  embedding_5 (Embedding)     (256, 32, 64, 42)         1806
#
#  conv1d_12 (Conv1D)          (256, 32, 64, 64)         8128
#
#  conv1d_13 (Conv1D)          (256, 32, 64, 64)         12352
#
#  conv1d_14 (Conv1D)          (256, 32, 64, 64)         12352
#
#  max_pooling2d_2 (MaxPooling  (256, 32, 1, 64)         0
#  2D)
#
#  tf.reshape_4 (TFOpLambda)   (256, 32, 64)             0
#
#  conv1d_15 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_16 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_17 (Conv1D)          (256, 32, 64)             12352
#
#  max_pooling1d_2 (MaxPooling  (256, 1, 64)             0
#  1D)
#
#  dense_4 (Dense)             (256, 1, 2048)            133120
#
#  dense_5 (Dense)             (256, 1, 1)               2049
#
#  tf.reshape_5 (TFOpLambda)   (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.5091WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 612ms/step - loss: 0.6945 - accuracy: 0.5091 - lr: 0.0010
# Epoch 2/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6622 - accuracy: 0.6081WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 614ms/step - loss: 0.6622 - accuracy: 0.6081 - lr: 0.0010
# Epoch 3/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6062 - accuracy: 0.7826WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 619ms/step - loss: 0.6062 - accuracy: 0.7826 - lr: 0.0010
# Epoch 4/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5830 - accuracy: 0.7975WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 636ms/step - loss: 0.5830 - accuracy: 0.7975 - lr: 0.0010
# Epoch 5/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5808 - accuracy: 0.7969WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 633ms/step - loss: 0.5808 - accuracy: 0.7969 - lr: 0.0010
# Epoch 6/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.7962WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 638ms/step - loss: 0.5819 - accuracy: 0.7962 - lr: 0.0010
# Epoch 7/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.7969WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 637ms/step - loss: 0.5821 - accuracy: 0.7969 - lr: 0.0010
# Epoch 8/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5804 - accuracy: 0.8001WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 631ms/step - loss: 0.5804 - accuracy: 0.8001 - lr: 0.0010
# Epoch 9/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5822 - accuracy: 0.7930WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 623ms/step - loss: 0.5822 - accuracy: 0.7930 - lr: 0.0010
# Epoch 10/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5811 - accuracy: 0.7969WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 632ms/step - loss: 0.5811 - accuracy: 0.7969 - lr: 0.0010
# Epoch 11/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5820 - accuracy: 0.7949WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 621ms/step - loss: 0.5820 - accuracy: 0.7949 - lr: 0.0010
# Epoch 12/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5827 - accuracy: 0.7975WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 630ms/step - loss: 0.5827 - accuracy: 0.7975 - lr: 0.0010
# Epoch 13/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5799 - accuracy: 0.8034WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 642ms/step - loss: 0.5799 - accuracy: 0.8034 - lr: 0.0010
# Epoch 14/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.8021WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 651ms/step - loss: 0.5816 - accuracy: 0.8021 - lr: 0.0010
# Epoch 15/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5810 - accuracy: 0.8086WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 633ms/step - loss: 0.5810 - accuracy: 0.8086 - lr: 0.0010
# Epoch 16/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.7630WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 643ms/step - loss: 0.5955 - accuracy: 0.7630 - lr: 0.0010
# (<keras.engine.functional.Functional at 0x1875aae4d60>,
#  <keras.callbacks.History at 0x1875aaca550>)

# %%
test_model(ablation=1000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_64_no_meta.pkl', train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)
# Out:
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 64
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 0
# length of train_data - (num_seq_per_cls * num_class)// batch size: 6
# <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 64), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(256, 32, 64)]           0
#
#  embedding_9 (Embedding)     (256, 32, 64, 42)         1806
#
#  conv1d_24 (Conv1D)          (256, 32, 64, 64)         8128
#
#  conv1d_25 (Conv1D)          (256, 32, 64, 64)         12352
#
#  conv1d_26 (Conv1D)          (256, 32, 64, 64)         12352
#
#  max_pooling2d_4 (MaxPooling  (256, 32, 1, 64)         0
#  2D)
#
#  tf.reshape_8 (TFOpLambda)   (256, 32, 64)             0
#
#  conv1d_27 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_28 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_29 (Conv1D)          (256, 32, 64)             12352
#
#  max_pooling1d_4 (MaxPooling  (256, 1, 64)             0
#  1D)
#
#  dense_8 (Dense)             (256, 1, 2048)            133120
#
#  dense_9 (Dense)             (256, 1, 1)               2049
#
#  tf.reshape_9 (TFOpLambda)   (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5091WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 654ms/step - loss: 0.6938 - accuracy: 0.5091 - lr: 0.0010
# Epoch 2/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6571 - accuracy: 0.6087WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 615ms/step - loss: 0.6571 - accuracy: 0.6087 - lr: 0.0010
# Epoch 3/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.7728WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 628ms/step - loss: 0.6016 - accuracy: 0.7728 - lr: 0.0010
# Epoch 4/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5824 - accuracy: 0.7962WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 638ms/step - loss: 0.5824 - accuracy: 0.7962 - lr: 0.0010
# Epoch 5/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.7962WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 639ms/step - loss: 0.5809 - accuracy: 0.7962 - lr: 0.0010
# Epoch 6/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5823 - accuracy: 0.7962WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 625ms/step - loss: 0.5823 - accuracy: 0.7962 - lr: 0.0010
# Epoch 7/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.8001WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 624ms/step - loss: 0.5816 - accuracy: 0.8001 - lr: 0.0010
# Epoch 8/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5931 - accuracy: 0.7871WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 630ms/step - loss: 0.5931 - accuracy: 0.7871 - lr: 0.0010
# Epoch 9/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.7227WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 632ms/step - loss: 0.6076 - accuracy: 0.7227 - lr: 0.0010
# Epoch 10/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5969 - accuracy: 0.7533WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 631ms/step - loss: 0.5969 - accuracy: 0.7533 - lr: 0.0010
# Epoch 11/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5971 - accuracy: 0.7526WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 638ms/step - loss: 0.5971 - accuracy: 0.7526 - lr: 0.0010
# Epoch 12/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.7559WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 635ms/step - loss: 0.5975 - accuracy: 0.7559 - lr: 0.0010
# Epoch 13/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.7578WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 638ms/step - loss: 0.5961 - accuracy: 0.7578 - lr: 0.0010
# Epoch 14/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5978 - accuracy: 0.7578WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 629ms/step - loss: 0.5978 - accuracy: 0.7578 - lr: 0.0010
# Epoch 15/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5957 - accuracy: 0.7539WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 627ms/step - loss: 0.5957 - accuracy: 0.7539 - lr: 0.0010
# Epoch 16/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.7565WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 4s 625ms/step - loss: 0.5975 - accuracy: 0.7565 - lr: 0.0010
# (<keras.engine.functional.Functional at 0x1875d7c5a30>,
#  <keras.callbacks.History at 0x18753248250>)

# %%
test_model(ablation=1000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_176_time_ip.pkl', train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)
# Out:
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 176
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 0
# length of train_data - (num_seq_per_cls * num_class)// batch size: 6
# <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(256, 32, 176)]          0
#
#  embedding_11 (Embedding)    (256, 32, 176, 42)        1806
#
#  conv1d_30 (Conv1D)          (256, 32, 176, 64)        8128
#
#  conv1d_31 (Conv1D)          (256, 32, 176, 64)        12352
#
#  conv1d_32 (Conv1D)          (256, 32, 176, 64)        12352
#
#  max_pooling2d_5 (MaxPooling  (256, 32, 1, 64)         0
#  2D)
#
#  tf.reshape_10 (TFOpLambda)  (256, 32, 64)             0
#
#  conv1d_33 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_34 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_35 (Conv1D)          (256, 32, 64)             12352
#
#  max_pooling1d_5 (MaxPooling  (256, 1, 64)             0
#  1D)
#
#  dense_10 (Dense)            (256, 1, 2048)            133120
#
#  dense_11 (Dense)            (256, 1, 1)               2049
#
#  tf.reshape_11 (TFOpLambda)  (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5091WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.6962 - accuracy: 0.5091 - lr: 0.0010
# Epoch 2/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6712 - accuracy: 0.5566WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.6712 - accuracy: 0.5566 - lr: 0.0010
# Epoch 3/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6092 - accuracy: 0.7982WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.6092 - accuracy: 0.7982 - lr: 0.0010
# Epoch 4/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5822 - accuracy: 0.8027WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5822 - accuracy: 0.8027 - lr: 0.0010
# Epoch 5/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.8053WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5792 - accuracy: 0.8053 - lr: 0.0010
# Epoch 6/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.8060WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5839 - accuracy: 0.8060 - lr: 0.0010
# Epoch 7/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5881 - accuracy: 0.7819WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5881 - accuracy: 0.7819 - lr: 0.0010
# Epoch 8/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.7995WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5809 - accuracy: 0.7995 - lr: 0.0010
# Epoch 9/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5814 - accuracy: 0.8008WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5814 - accuracy: 0.8008 - lr: 0.0010
# Epoch 10/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5773 - accuracy: 0.8223WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5773 - accuracy: 0.8223 - lr: 0.0010
# Epoch 11/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5862 - accuracy: 0.8008WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5862 - accuracy: 0.8008 - lr: 0.0010
# Epoch 12/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5840 - accuracy: 0.8034WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.5840 - accuracy: 0.8034 - lr: 0.0010
# Epoch 13/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5820 - accuracy: 0.8040WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.5820 - accuracy: 0.8040 - lr: 0.0010
# Epoch 14/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5825 - accuracy: 0.8073WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5825 - accuracy: 0.8073 - lr: 0.0010
# Epoch 15/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.8060WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.5793 - accuracy: 0.8060 - lr: 0.0010
# Epoch 16/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5765 - accuracy: 0.8223WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 12s 2s/step - loss: 0.5765 - accuracy: 0.8223 - lr: 0.0010
# (<keras.engine.functional.Functional at 0x1875db49310>,
#  <keras.callbacks.History at 0x1875db57670>)

# %%
test_model(ablation=1000, batch_size=256, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True,
          hdfs_obJ_full_name='data\\hdfsobj_32_176_no_meta.pkl', train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)
# Out:
# train_hdfs_anomaly:, 800, val_hdfs_anomaly:, 100, test_hdfs_anomaly:, 100, train_hdfs_normal:, 800, val_hdfs_normal:, 100, test_hdfs_normal:, 100, train: hdfs_anomaly    800
# hdfs_normal     800
# Name: label, dtype: int64
# val: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# test: hdfs_anomaly    100
# hdfs_normal     100
# Name: label, dtype: int64
# train_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 176
# num classes, train_data.element_spec[1].shape:  (256,)
# length of val_data: 0
# length of train_data - (num_seq_per_cls * num_class)// batch size: 6
# <BatchDataset element_spec=(TensorSpec(shape=(256, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(256,), dtype=tf.int32, name=None))>
# vocab_size: 42
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(256, 32, 176)]          0
#
#  embedding_13 (Embedding)    (256, 32, 176, 42)        1806
#
#  conv1d_36 (Conv1D)          (256, 32, 176, 64)        8128
#
#  conv1d_37 (Conv1D)          (256, 32, 176, 64)        12352
#
#  conv1d_38 (Conv1D)          (256, 32, 176, 64)        12352
#
#  max_pooling2d_6 (MaxPooling  (256, 32, 1, 64)         0
#  2D)
#
#  tf.reshape_12 (TFOpLambda)  (256, 32, 64)             0
#
#  conv1d_39 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_40 (Conv1D)          (256, 32, 64)             12352
#
#  conv1d_41 (Conv1D)          (256, 32, 64)             12352
#
#  max_pooling1d_6 (MaxPooling  (256, 1, 64)             0
#  1D)
#
#  dense_12 (Dense)            (256, 1, 2048)            133120
#
#  dense_13 (Dense)            (256, 1, 1)               2049
#
#  tf.reshape_13 (TFOpLambda)  (256, 1)                  0
#
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6952 - accuracy: 0.5091WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.6952 - accuracy: 0.5091 - lr: 0.0010
# Epoch 2/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.5931WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.6618 - accuracy: 0.5931 - lr: 0.0010
# Epoch 3/16
# 6/6 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.7839WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.6038 - accuracy: 0.7839 - lr: 0.0010
# Epoch 4/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5820 - accuracy: 0.7969WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.5820 - accuracy: 0.7969 - lr: 0.0010
# Epoch 5/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5791 - accuracy: 0.8001WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.5791 - accuracy: 0.8001 - lr: 0.0010
# Epoch 6/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5867 - accuracy: 0.8001WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 11s 2s/step - loss: 0.5867 - accuracy: 0.8001 - lr: 0.0010
# Epoch 7/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5939 - accuracy: 0.7643WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5939 - accuracy: 0.7643 - lr: 0.0010
# Epoch 8/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5855 - accuracy: 0.7884WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5855 - accuracy: 0.7884 - lr: 0.0010
# Epoch 9/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5840 - accuracy: 0.7936WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5840 - accuracy: 0.7936 - lr: 0.0010
# Epoch 10/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5769 - accuracy: 0.8164WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5769 - accuracy: 0.8164 - lr: 0.0010
# Epoch 11/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5786 - accuracy: 0.8249WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5786 - accuracy: 0.8249 - lr: 0.0010
# Epoch 12/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5744 - accuracy: 0.8320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5744 - accuracy: 0.8320 - lr: 0.0010
# Epoch 13/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5718 - accuracy: 0.8340WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5718 - accuracy: 0.8340 - lr: 0.0010
# Epoch 14/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5713 - accuracy: 0.8398WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5713 - accuracy: 0.8398 - lr: 0.0010
# Epoch 15/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5682 - accuracy: 0.8418WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5682 - accuracy: 0.8418 - lr: 0.0010
# Epoch 16/16
# 6/6 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.8398WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy,lr
# 6/6 [==============================] - 10s 2s/step - loss: 0.5708 - accuracy: 0.8398 - lr: 0.0010
# (<keras.engine.functional.Functional at 0x187503d3df0>,
#  <keras.callbacks.History at 0x187503d7e50>)

# %%
import os
hdfs_obJ_full_name='data\\hdfsobj_32_176_time_ip.pkl'

# %%
p = os.path.abspath(hdfs_obJ_full_name)

# %%
os.path.abspath(p)
# Out:
# 'C:\\Users\\Bhujay_ROG\\MyDev\\OCLog\\oclog\\hdfs\\data\\hdfsobj_32_176_time_ip.pkl'
