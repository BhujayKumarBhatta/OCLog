# %%
def test_model(ablation=1000, B=32, epochs=3, filters=64, kernel_size=3, dense_neurons=2048, 
              conv1d_set1=1, conv1d_set2=1, maxpool_1=False):
    from hdflogv2 import HDFSLogv2
    import tensorflow as tf
    import numpy as np
    tf.random.set_seed(123)
    import pickle
    with open('../data/hdfslogs_v2.pkl', 'rb') as f:
        hdfslogs = pickle.load(f)
    ablation_data = hdfslogs.get_train_test_data(ablation=ablation)
    x_train, y_train, x_test, y_test = hdfslogs.get_padded_train_test_data(ablation=ablation)
    train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_data = train_data.shuffle(buffer_size=y_train.shape[0]).batch(B, drop_remainder=True)
    print(train_data)
    
    test_data = tf.data.Dataset.from_tensor_slices((x_test, y_test))
    test_data = test_data.shuffle(buffer_size=y_test.shape[0]).batch(B, drop_remainder=True)
    print(test_data)
    
    
    tk = hdfslogs.tk    
    vocab_size = len(tk.word_index)
    print(f'vocab_size: {vocab_size}')
    char_onehot = vocab_size
    
    embedding_weights = []
    embedding_weights.append(np.zeros(vocab_size))
    for char, i in tk.word_index.items(): # from 1 to 51
        onehot = np.zeros(vocab_size)
        onehot[i-1] = 1
        embedding_weights.append(onehot)
    embedding_weights = np.array(embedding_weights)
    
    input_size = [x_train.shape[1], x_train.shape[2]]
    embedding_size = vocab_size

    embedding_layer = tf.keras.layers.Embedding(vocab_size+1,
                                                embedding_size,
                                                input_length=input_size,
                                                weights = [embedding_weights])
    
    
    
    
    inputs = tf.keras.layers.Input(batch_shape=(B, x_train.shape[1], x_train.shape[2]), dtype='float64' )
    x = tf.keras.layers.Embedding(input_dim=vocab_size+1,
                                    output_dim=embedding_size,
                                    input_length=x_train.shape[2],
                                    weights = [embedding_weights],
                                    )(inputs)
    for _ in range(conv1d_set1):
        x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    if maxpool_1:
        x = tf.keras.layers.MaxPooling2D(pool_size=(1, x_train.shape[2]))(x)
        x = tf.reshape(x, (B, x_train.shape[1], filters))        
        for _ in range(conv1d_set2):
            x = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
        x = tf.keras.layers.MaxPooling1D(pool_size=(x_train.shape[1]) )(x)    
    if not maxpool_1:
        x = tf.keras.layers.Flatten()(x)       
    x = tf.keras.layers.Dense(dense_neurons)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    print(model.summary())
    model.compile(optimizer='adam', 
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
    hist = model.fit(train_data, validation_data=test_data, epochs=epochs) 
    return model, hist

# %%
test_model(ablation=4000, B=250, kernel_size=3, epochs=16, dense_neurons=2048, conv1d_set1=3,conv1d_set2=3, maxpool_1=True )
# Out:
# getting ablation data: 4000
# ablation x_test positive: 4000
# total x_test negative: 554223
# 0.8 % split ratio of positve class, train:4000, test:4000
# <BatchDataset shapes: ((250, 64, 256), (250,)), types: (tf.int32, tf.int64)>
# <BatchDataset shapes: ((250, 64, 256), (250,)), types: (tf.int32, tf.int64)>
# vocab_size: 42
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(250, 64, 256)]          0
# _________________________________________________________________
# embedding_1 (Embedding)      (250, 64, 256, 42)        1806
# _________________________________________________________________
# conv1d (Conv1D)              (250, 64, 256, 64)        8128
# _________________________________________________________________
# conv1d_1 (Conv1D)            (250, 64, 256, 64)        12352
# _________________________________________________________________
# conv1d_2 (Conv1D)            (250, 64, 256, 64)        12352
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (250, 64, 1, 64)          0
# _________________________________________________________________
# tf_op_layer_Reshape (TensorF [(250, 64, 64)]           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (250, 64, 64)             12352
# _________________________________________________________________
# conv1d_4 (Conv1D)            (250, 64, 64)             12352
# _________________________________________________________________
# conv1d_5 (Conv1D)            (250, 64, 64)             12352
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (250, 1, 64)              0
# _________________________________________________________________
# dense (Dense)                (250, 1, 2048)            133120
# _________________________________________________________________
# dense_1 (Dense)              (250, 1, 1)               2049
# =================================================================
# Total params: 206,863
# Trainable params: 206,863
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/16
# 32/32 [==============================] - 897s 28s/step - loss: 0.6263 - accuracy: 0.6856 - val_loss: 0.6301 - val_accuracy: 0.6694
# Epoch 2/16
# 32/32 [==============================] - 873s 27s/step - loss: 0.6039 - accuracy: 0.7352 - val_loss: 0.6007 - val_accuracy: 0.7434
# Epoch 3/16
# 32/32 [==============================] - 883s 28s/step - loss: 0.6008 - accuracy: 0.7430 - val_loss: 0.6006 - val_accuracy: 0.7436
# Epoch 4/16
# 32/32 [==============================] - 861s 27s/step - loss: 0.6008 - accuracy: 0.7430 - val_loss: 0.6006 - val_accuracy: 0.7436
# Epoch 5/16
# 32/32 [==============================] - 851s 27s/step - loss: 0.5976 - accuracy: 0.7565 - val_loss: 0.5956 - val_accuracy: 0.7728
# Epoch 6/16
# 32/32 [==============================] - 894s 28s/step - loss: 0.5952 - accuracy: 0.7614 - val_loss: 0.5934 - val_accuracy: 0.7719
# Epoch 7/16
# 32/32 [==============================] - 874s 27s/step - loss: 0.5945 - accuracy: 0.7692 - val_loss: 0.5937 - val_accuracy: 0.7738
# Epoch 8/16
# 32/32 [==============================] - 904s 28s/step - loss: 0.5726 - accuracy: 0.8290 - val_loss: 0.5517 - val_accuracy: 0.8709
# Epoch 9/16
# 32/32 [==============================] - 858s 27s/step - loss: 0.5263 - accuracy: 0.9426 - val_loss: 0.5192 - val_accuracy: 0.9588
# Epoch 10/16
# 32/32 [==============================] - 895s 28s/step - loss: 0.5195 - accuracy: 0.9591 - val_loss: 0.5133 - val_accuracy: 0.9750
# Epoch 11/16
# 32/32 [==============================] - 882s 28s/step - loss: 0.5075 - accuracy: 0.9905 - val_loss: 0.5045 - val_accuracy: 0.9980
# Epoch 12/16
# 32/32 [==============================] - 866s 27s/step - loss: 0.5045 - accuracy: 0.9977 - val_loss: 0.5045 - val_accuracy: 0.9977
# Epoch 13/16
# 13/32 [===========>..................] - ETA: 8:27 - loss: 0.5064 - accuracy: 0.9969
