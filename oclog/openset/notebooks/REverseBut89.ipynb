# %%
import os, sys
cur_dir = os.getcwd()
basename = os.path.basename(cur_dir)
for _ in range(5):
    if basename != 'OCLog':
        cur_dir = os.path.dirname(cur_dir)
        basename = os.path.basename(cur_dir)
        #print(cur_dir, basename)
    else:
        if cur_dir not in sys.path:
            sys.path.append(cur_dir)
            #print(sys.path)
import os
from openpyxl import Workbook
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tqdm import trange, tqdm, tnrange
from oclog.BGL.bglv1 import BGLog
from oclog.openset.opensetv12 import OpenSet
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
import sklearn.metrics as m
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.manifold import TSNE
tf.random.set_seed(1234)
np.random.seed(1234) 
# tf.random.set_seed(1234)
# np.random.seed(1234)

# %%
oset = OpenSet()
train_data, val_data,  test_data, bglog  = oset.get_bgdata(bg_class_obj=BGLog, save_padded_num_sequences=False, 
                                                           load_from_pkl=True, ablation=1500,
                                                           debug=False,
                                                          designated_ukc_cls=5)
# Out:
# extracting all the values from your input parameter
# padded_num_seq_df loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc.pkl
# trained tokenizer, tk, loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_tk.pkl
# train_0:, 1200, val_0:, 150, test_0:, 150, train_1:, 1200, val_1:, 150, test_1:, 150, train_2:, 1200, val_2:, 150, test_2:, 150, class 5 is added as ukc
# ukc_5:, 150
# length of train_data - (num_seq_per_cls * num_class)// batch size: 112
# get_bgdata  num_classses: 3 and self.num_classes: 3

# %%
# res = oset.ptmodel_custom_train(train_data=train_data, val_data=val_data,
#                  test_data=test_data, bglog=bglog, 
#                  manual_color_map=True, centroid_black=True,                               
#                  tsne_n_iter=2000, tsne_perplexity=8,
#                  embedding_size=12, oc_lr=2.5, pt_epochs=5, oc_epochs=2,
#                 save_ptmodel=False, save_ocmodel=False, oc_centroid_plot=False,
#                                halpha=0.7, hbeta=1.5, batch_normalize=True )
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=40,
                oc_lr=0.18, oc_epochs=40, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# extracting all the values from your input parameter
# vocab_size: 50
# 2022-05-11 16:04:33.943136
# starting to create ptmodel automatically
# epoch: 1/40, train_loss: 3.846605062484741, train_acc: 52.26, F1_train: 0.4253 val_loss: 3.846605062484741, val_acc: 59.38,, F1_val: 0.4985
# epoch: 2/40, train_loss: 2.8630712032318115, train_acc: 50.95, F1_train: 0.4073 val_loss: 2.8630712032318115, val_acc: 61.61,, F1_val: 0.5088
# epoch: 3/40, train_loss: 2.4504919052124023, train_acc: 62.28, F1_train: 0.6216 val_loss: 2.4504919052124023, val_acc: 91.29,, F1_val: 0.9095
# epoch: 4/40, train_loss: 2.0752928256988525, train_acc: 56.67, F1_train: 0.5141 val_loss: 2.0752928256988525, val_acc: 63.84,, F1_val: 0.5386
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# epoch: 40/40, train_loss: 0.6227150559425354, train_acc: 99.47, F1_train: 0.9947 val_loss: 0.6227150559425354, val_acc: 100.0,, F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# run_id:  2022-05-11_16_11_49.777796_f690432ad11611ec8594ac8247733f47
# got all the dataset
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
# run_id:  2022-05-11_16_12_09.656533_02698455d11711ecb136ac8247733f47
# unknown optimizer None. assigning default as adam with lr_rate=0.18
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 1/40, train_loss: 0.481184184551239, F1_train: 0.9346816266224861 F1_val: 0.9874749565471215,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.51it/s]
# epoch: 2/40, train_loss: 0.48110511898994446, F1_train: 0.9156246352122798 F1_val: 0.98158034670403,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.36it/s]
# epoch: 3/40, train_loss: 0.481224000453949, F1_train: 0.8854970241026022 F1_val: 0.9742893586005831,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.16it/s]
# epoch: 4/40, train_loss: 0.48097267746925354, F1_train: 0.8599963008729824 F1_val: 0.9706188306508171,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.33it/s]
# epoch: 5/40, train_loss: 0.48094460368156433, F1_train: 0.8389110282145064 F1_val: 0.9693409770174627,
# train score not improving  going to wait state 4
# val score not improving  going to wait state 4
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.51it/s]
# epoch: 6/40, train_loss: 0.48143142461776733, F1_train: 0.8205478311130324 F1_val: 0.9643284633377042,
# train score not improving  going to wait state 5
# val score not improving  going to wait state 5
# Best readius assigen as [[0.5996578 ]
#  [0.63607025]
#  [0.6044429 ]]
# classification report for training:
# [[1175    0    0   17]
#  [   0  938    0  259]
#  [   0    0 1130   65]
#  [   0    0    0    0]]
# 90.49
# f1_weighted: 0.9477735809274926, f1_macro: 0.7108873620782141, f1_micro: 0.9048549107142856, f_measure: {'Known': 94.785, 'Open': 0, 'F1-score': 71.0887}
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1192
#            1       1.00      0.78      0.88      1197
#            2       1.00      0.95      0.97      1195
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.90      3584
#    macro avg       0.75      0.68      0.71      3584
# weighted avg       1.00      0.90      0.95      3584
#
# classification report for test data:
# [[142   0   0   0]
#  [  0 147   0   0]
#  [  0   1 107  36]
#  [  2   0   0 141]]
# 93.23
# f1_weighted: 0.9310769900846895, f1_macro: 0.9308642009831953, f1_micro: 0.9322916666666666, f_measure: {'Known': 94.7402, 'Open': 88.125, 'F1-score': 93.0864}
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       142
#            1       0.99      1.00      1.00       147
#            2       1.00      0.74      0.85       144
#            5       0.80      0.99      0.88       143
#
#     accuracy                           0.93       576
#    macro avg       0.94      0.93      0.93       576
# weighted avg       0.94      0.93      0.93       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=40,
                oc_lr=0.09, oc_epochs=40, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, )
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.09
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 1/40, train_loss: 0.461452454328537, F1_train: 0.9448951990009894 F1_val: 0.994370841686278,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 2/40, train_loss: 0.46125999093055725, F1_train: 0.940345206059231 F1_val: 0.9898004466330738,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.50it/s]
# epoch: 3/40, train_loss: 0.4619445204734802, F1_train: 0.9353661647172089 F1_val: 0.9874754129292092,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.44it/s]
# epoch: 4/40, train_loss: 0.4614262878894806, F1_train: 0.932458874779998 F1_val: 0.9886183568990735,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.50it/s]
# epoch: 5/40, train_loss: 0.46115991473197937, F1_train: 0.9288678478358843 F1_val: 0.9851518707088128,
# train score not improving  going to wait state 4
# val score not improving  going to wait state 4
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 6/40, train_loss: 0.4609622657299042, F1_train: 0.9251783864976307 F1_val: 0.9839691130049714,
# train score not improving  going to wait state 5
# val score not improving  going to wait state 5
# Best readius assigen as [[0.61363643]
#  [0.62235266]
#  [0.6083616 ]]
# classification report for training:
# [[1178    0    0   16]
#  [   0  932    0  262]
#  [   0    0 1132   64]
#  [   0    0    0    0]]
# 90.46
# f1_weighted: 0.9475229854203165, f1_macro: 0.7106317760812991, f1_micro: 0.9045758928571429, f_measure: {'Known': 94.7509, 'Open': 0, 'F1-score': 71.0632}
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1194
#            1       1.00      0.78      0.88      1194
#            2       1.00      0.95      0.97      1196
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.90      3584
#    macro avg       0.75      0.68      0.71      3584
# weighted avg       1.00      0.90      0.95      3584
#
# classification report for test data:
# [[144   0   0   0]
#  [  0 149   0   0]
#  [  0   1 103  35]
#  [  2   0   0 142]]
# 93.4
# f1_weighted: 0.9326957500017224, f1_macro: 0.9314334596460526, f1_micro: 0.9340277777777778, f_measure: {'Known': 94.7, 'Open': 88.4735, 'F1-score': 93.1433}
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       144
#            1       0.99      1.00      1.00       149
#            2       1.00      0.74      0.85       139
#            5       0.80      0.99      0.88       144
#
#     accuracy                           0.93       576
#    macro avg       0.95      0.93      0.93       576
# weighted avg       0.95      0.93      0.93       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=40,
                oc_lr=0.05, oc_epochs=40, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, )
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.05
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 1/40, train_loss: 0.4637600779533386, F1_train: 0.9499803472277433 F1_val: 0.9943707404644905,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 2/40, train_loss: 0.4638335406780243, F1_train: 0.9478941767342998 F1_val: 0.9943706123957945,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 3/40, train_loss: 0.4635874629020691, F1_train: 0.9466543292558368 F1_val: 0.994370511174007,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.44it/s]
# epoch: 4/40, train_loss: 0.46358639001846313, F1_train: 0.9460281569708481 F1_val: 0.9909499514091351,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 5/40, train_loss: 0.463782399892807, F1_train: 0.9445489764439862 F1_val: 0.9909499514091351,
# train score not improving  going to wait state 4
# val score not improving  going to wait state 4
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 6/40, train_loss: 0.46330222487449646, F1_train: 0.9439053932923601 F1_val: 0.9909503618049537,
# train score not improving  going to wait state 5
# val score not improving  going to wait state 5
# Best readius assigen as [[0.6228921 ]
#  [0.6933317 ]
#  [0.63353986]]
# classification report for training:
# [[1177    0    0   16]
#  [   0  959    0  238]
#  [   0    0 1137   57]
#  [   0    0    0    0]]
# 91.32
# f1_weighted: 0.9527379231941703, f1_macro: 0.7146015775762611, f1_micro: 0.9132254464285714, f_measure: {'Known': 95.2802, 'Open': 0, 'F1-score': 71.4602}
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1193
#            1       1.00      0.80      0.89      1197
#            2       1.00      0.95      0.98      1194
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.91      3584
#    macro avg       0.75      0.69      0.71      3584
# weighted avg       1.00      0.91      0.95      3584
#
# classification report for test data:
# [[145   0   0   0]
#  [  0 142   0   0]
#  [  0   2 111  32]
#  [  2   0   0 142]]
# 93.75
# f1_weighted: 0.9363885475815401, f1_macro: 0.9366067347361973, f1_micro: 0.9375, f_measure: {'Known': 95.1115, 'Open': 89.3082, 'F1-score': 93.6607}
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       145
#            1       0.99      1.00      0.99       142
#            2       1.00      0.77      0.87       145
#            5       0.82      0.99      0.89       144
#
#     accuracy                           0.94       576
#    macro avg       0.95      0.94      0.94       576
# weighted avg       0.95      0.94      0.94       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=40,
                oc_lr=0.01, oc_epochs=40, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, )
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.01
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 1/40, train_loss: 0.47155317664146423, F1_train: 0.955014864238948 F1_val: 0.9977603415103415,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.39it/s]
# epoch: 2/40, train_loss: 0.47127658128738403, F1_train: 0.9545309812700215 F1_val: 0.9977603666462362,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.45it/s]
# epoch: 3/40, train_loss: 0.4718732535839081, F1_train: 0.9541786528594756 F1_val: 0.9977603666462362,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 4/40, train_loss: 0.4713168740272522, F1_train: 0.9541670258178717 F1_val: 0.9977603415103415,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.40it/s]
# epoch: 5/40, train_loss: 0.47136086225509644, F1_train: 0.9543219460771215 F1_val: 0.9977603415103415,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.36it/s]
# epoch: 6/40, train_loss: 0.47125548124313354, F1_train: 0.9541746096499929 F1_val: 0.9977603415103415,
# train score not improving  going to wait state 4
# val score not improving  going to wait state 4
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.42it/s]
# epoch: 7/40, train_loss: 0.4712068438529968, F1_train: 0.954035149213058 F1_val: 0.9977603666462362,
# train score not improving  going to wait state 5
# val score not improving  going to wait state 5
# Best readius assigen as [[0.6575633]
#  [0.6632513]
#  [0.7179394]]
# classification report for training:
# [[1182    0    0   12]
#  [   0  942    0  252]
#  [   0    0 1163   33]
#  [   0    0    0    0]]
# 91.71
# f1_weighted: 0.9543453432720675, f1_macro: 0.7157457471197344, f1_micro: 0.9171316964285714, f_measure: {'Known': 95.4328, 'Open': 0, 'F1-score': 71.5746}
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1194
#            1       1.00      0.79      0.88      1194
#            2       1.00      0.97      0.99      1196
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.92      3584
#    macro avg       0.75      0.69      0.72      3584
# weighted avg       1.00      0.92      0.95      3584
#
# classification report for test data:
# [[144   0   0   0]
#  [  0 142   0   0]
#  [  0   1 115  31]
#  [  3   0   0 140]]
# 93.92
# f1_weighted: 0.9385051100643876, f1_macro: 0.9389410725906093, f1_micro: 0.9392361111111112, f_measure: {'Known': 95.4682, 'Open': 89.172, 'F1-score': 93.8941}
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       144
#            1       0.99      1.00      1.00       142
#            2       1.00      0.78      0.88       147
#            5       0.82      0.98      0.89       143
#
#     accuracy                           0.94       576
#    macro avg       0.95      0.94      0.94       576
# weighted avg       0.95      0.94      0.94       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=40,
                oc_lr=0.001, oc_epochs=40, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, )
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.001
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.47it/s]
# epoch: 1/40, train_loss: 0.47731682658195496, F1_train: 0.9584534279206066 F1_val: 0.9988801707551708,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.03it/s]
# epoch: 2/40, train_loss: 0.4774028956890106, F1_train: 0.9583162723892477 F1_val: 0.9988801707551708,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 3/40, train_loss: 0.4771259129047394, F1_train: 0.9581454555241289 F1_val: 0.9988801707551708,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 4/40, train_loss: 0.4772341549396515, F1_train: 0.9583100085500299 F1_val: 0.9988801707551708,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 5/40, train_loss: 0.4770045876502991, F1_train: 0.9578003163188916 F1_val: 0.9988801958910655,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 6/40, train_loss: 0.4771609306335449, F1_train: 0.9579807944828646 F1_val: 0.9988801958910655,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 7/40, train_loss: 0.4774594008922577, F1_train: 0.9578098173278121 F1_val: 0.9988801958910655,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.15it/s]
# epoch: 8/40, train_loss: 0.47727951407432556, F1_train: 0.9579682371242095 F1_val: 0.9988801958910655,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.39it/s]
# epoch: 9/40, train_loss: 0.4768928587436676, F1_train: 0.9582888816734637 F1_val: 0.9988801958910655,
# train score not improving  going to wait state 4
# val score not improving  going to wait state 4
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.44it/s]
# epoch: 10/40, train_loss: 0.47673720121383667, F1_train: 0.9580846048628997 F1_val: 0.9988801707551708,
# train score not improving  going to wait state 5
# val score not improving  going to wait state 5
# Best readius assigen as [[0.66454697]
#  [0.7139788 ]
#  [0.7084797 ]]
# classification report for training:
# [[1185    0    0   12]
#  [   0  965    0  231]
#  [   0    0 1158   33]
#  [   0    0    0    0]]
# 92.3
# f1_weighted: 0.9579775683903391, f1_macro: 0.7185046823239759, f1_micro: 0.9229910714285714, f_measure: {'Known': 95.8006, 'Open': 0, 'F1-score': 71.8505}
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1197
#            1       1.00      0.81      0.89      1196
#            2       1.00      0.97      0.99      1191
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.92      3584
#    macro avg       0.75      0.69      0.72      3584
# weighted avg       1.00      0.92      0.96      3584
#
# classification report for test data:
# [[145   0   0   0]
#  [  0 142   0   0]
#  [  0   2 112  30]
#  [  3   0   0 142]]
# 93.92
# f1_weighted: 0.9382425592791547, f1_macro: 0.938416784696231, f1_micro: 0.9392361111111112, f_measure: {'Known': 95.2589, 'Open': 89.5899, 'F1-score': 93.8417}
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       145
#            1       0.99      1.00      0.99       142
#            2       1.00      0.78      0.88       144
#            5       0.83      0.98      0.90       145
#
#     accuracy                           0.94       576
#    macro avg       0.95      0.94      0.94       576
# weighted avg       0.95      0.94      0.94       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
