# %%
import os, sys
cur_dir = os.getcwd()
basename = os.path.basename(cur_dir)
for _ in range(5):
    if basename != 'OCLog':
        cur_dir = os.path.dirname(cur_dir)
        basename = os.path.basename(cur_dir)
        #print(cur_dir, basename)
    else:
        if cur_dir not in sys.path:
            sys.path.append(cur_dir)
            #print(sys.path)
import os
from openpyxl import Workbook
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tqdm import trange, tqdm, tnrange
from oclog.BGL.bglv1 import BGLog
from oclog.openset.opensetv12 import OpenSet
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
import sklearn.metrics as m
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.manifold import TSNE
tf.random.set_seed(1234)
np.random.seed(1234) 
# tf.random.set_seed(1234)
# np.random.seed(1234)

# %%
oset = OpenSet()
train_data, val_data,  test_data, bglog  = oset.get_bgdata(bg_class_obj=BGLog, save_padded_num_sequences=False, 
                                                           load_from_pkl=True, ablation=1500,
                                                           debug=False,
                                                          designated_ukc_cls=5)
# Out:
# extracting all the values from your input parameter
# padded_num_seq_df loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc.pkl
# trained tokenizer, tk, loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_tk.pkl
# train_0:, 1200, val_0:, 150, test_0:, 150, train_1:, 1200, val_1:, 150, test_1:, 150, train_2:, 1200, val_2:, 150, test_2:, 150, class 5 is added as ukc
# ukc_5:, 150
# length of train_data - (num_seq_per_cls * num_class)// batch size: 112
# get_bgdata  num_classses: 3 and self.num_classes: 3

# %%
# res = oset.ptmodel_custom_train(train_data=train_data, val_data=val_data,
#                  test_data=test_data, bglog=bglog, 
#                  manual_color_map=True, centroid_black=True,                               
#                  tsne_n_iter=2000, tsne_perplexity=8,
#                  embedding_size=12, oc_lr=2.5, pt_epochs=5, oc_epochs=2,
#                 save_ptmodel=False, save_ocmodel=False, oc_centroid_plot=False,
#                                halpha=0.7, hbeta=1.5, batch_normalize=True )


res = oset.train(train_data=train_data, val_data=val_data,
                 test_data=test_data, bglog=bglog, 
                 manual_color_map=True, centroid_black=True,                               
                 tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, oc_lr=0.38, pt_epochs=10, oc_epochs=10, oc_wait=5, 
                save_ptmodel=False, save_ocmodel=False, oc_centroid_plot=True,
                               halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True )
# Out:
# extracting all the values from your input parameter
# got all the dataset
# extracting all the values from your input parameter
# vocab_size: 50
# 2022-05-11 09:35:19.923979
# starting to create ptmodel automatically
# epoch: 1/10, train_loss: 3.846605062484741, train_acc: 52.26, F1_train: 0.4253 val_loss: 3.846605062484741, val_acc: 59.38,, F1_val: 0.4985
# epoch: 2/10, train_loss: 2.8630712032318115, train_acc: 50.95, F1_train: 0.4073 val_loss: 2.8630712032318115, val_acc: 61.61,, F1_val: 0.5088
# epoch: 3/10, train_loss: 2.4504919052124023, train_acc: 62.28, F1_train: 0.6216 val_loss: 2.4504919052124023, val_acc: 91.29,, F1_val: 0.9095
# epoch: 4/10, train_loss: 2.0752928256988525, train_acc: 56.67, F1_train: 0.5141 val_loss: 2.0752928256988525, val_acc: 63.84,, F1_val: 0.5386
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# epoch: 5/10, train_loss: 1.730332851409912, train_acc: 87.5, F1_train: 0.8739 val_loss: 1.730332851409912, val_acc: 99.55,, F1_val: 0.9955
# epoch: 6/10, train_loss: 1.5815356969833374, train_acc: 94.2, F1_train: 0.9413 val_loss: 1.5815356969833374, val_acc: 99.78,, F1_val: 0.9978
# epoch: 7/10, train_loss: 1.4836366176605225, train_acc: 94.5, F1_train: 0.9445 val_loss: 1.4836366176605225, val_acc: 99.78,, F1_val: 0.9978
# epoch: 8/10, train_loss: 1.3438355922698975, train_acc: 95.62, F1_train: 0.9559 val_loss: 1.3438355922698975, val_acc: 99.55,, F1_val: 0.9955
# epoch: 9/10, train_loss: 1.2702858448028564, train_acc: 95.62, F1_train: 0.9558 val_loss: 1.2702858448028564, val_acc: 99.78,, F1_val: 0.9978
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# epoch: 10/10, train_loss: 1.220235824584961, train_acc: 95.56, F1_train: 0.955 val_loss: 1.220235824584961, val_acc: 99.78,, F1_val: 0.9978
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# run_id:  2022-05-11_09_37_08.407898_d35dfb8dd0df11ec8594ac8247733f47
# got all the dataset
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
# run_id:  2022-05-11_09_37_28.168228_df252b6ad0df11ecb136ac8247733f47
# unknown optimizer None. assigning default as adam with lr_rate=0.38
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.47it/s]
# epoch: 1/10, train_loss: 0.3423517048358917, F1_train: 0.8515091082837328 F1_val: 0.9716852435926578
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.40it/s]
# epoch: 2/10, train_loss: 0.34281083941459656, F1_train: 0.8965763602907063 F1_val: 0.9873974731819448
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.33it/s]
# epoch: 3/10, train_loss: 0.34168705344200134, F1_train: 0.0 F1_val: 0.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.41it/s]
# epoch: 4/10, train_loss: 0.3424406945705414, F1_train: 0.9316085229272788 F1_val: 0.9885929802955664
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 5/10, train_loss: 0.3425440788269043, F1_train: 0.0 F1_val: 0.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 6/10, train_loss: 0.3427228331565857, F1_train: 0.9414823955481442 F1_val: 0.993243268379138
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 7/10, train_loss: 0.34234434366226196, F1_train: 0.4952443176186398 F1_val: 0.5699446070563056
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 8/10, train_loss: 0.3430703580379486, F1_train: 0.9449055712494163 F1_val: 0.9955207083252751
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.44it/s]
# epoch: 9/10, train_loss: 0.3423968255519867, F1_train: 0.9467418211306403 F1_val: 0.9955207083252751
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 10/10, train_loss: 0.3421878218650818, F1_train: 0.94859825861673 F1_val: 0.9955206322393823
# classification report for training:
# [[1161   11    0   22]
#  [  41  946    0  206]
#  [   0    0 1183   14]
#  [   0    0    0    0]]
# 91.8
# f1_weighted: 0.9478019985383551, f1_macro: 0.7108082097613669, f1_micro: 0.91796875, f_measure: {'Known': 94.7744, 'Open': 0, 'F1-score': 71.0808}
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1194
#            1       0.99      0.79      0.88      1193
#            2       1.00      0.99      0.99      1197
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.92      3584
#    macro avg       0.74      0.69      0.71      3584
# weighted avg       0.98      0.92      0.95      3584
#
# classification report for test data:
# [[141   1   0   0]
#  [  0 147   0   0]
#  [  0   0 122  22]
#  [ 46  16   0  81]]
# 85.24
# f1_weighted: 0.8453817243239461, f1_macro: 0.844577574042549, f1_micro: 0.8524305555555556, f_measure: {'Known': 90.6591, 'Open': 65.8537, 'F1-score': 84.4578}
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.86       142
#            1       0.90      1.00      0.95       147
#            2       1.00      0.85      0.92       144
#            5       0.79      0.57      0.66       143
#
#     accuracy                           0.85       576
#    macro avg       0.86      0.85      0.84       576
# weighted avg       0.86      0.85      0.85       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
