# %%
import os, sys
cur_dir = os.getcwd()
basename = os.path.basename(cur_dir)
for _ in range(5):
    if basename != 'OCLog':
        cur_dir = os.path.dirname(cur_dir)
        basename = os.path.basename(cur_dir)
        #print(cur_dir, basename)
    else:
        if cur_dir not in sys.path:
            sys.path.append(cur_dir)
            #print(sys.path)
import os
from openpyxl import Workbook
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tqdm import trange, tqdm, tnrange
from oclog.BGL.bglv1 import BGLog
from oclog.openset.opensetv12 import OpenSet
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
import sklearn.metrics as m
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.manifold import TSNE
tf.random.set_seed(1234)
np.random.seed(1234) 
# tf.random.set_seed(1234)
# np.random.seed(1234)

# %%
oset = OpenSet()
train_data, val_data,  test_data, bglog  = oset.get_bgdata(bg_class_obj=BGLog, save_padded_num_sequences=False, 
                                                           load_from_pkl=True, ablation=1500,
                                                           debug=False,
                                                          designated_ukc_cls=5)
# Out:
# extracting all the values from your input parameter
# padded_num_seq_df loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc.pkl
# trained tokenizer, tk, loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_tk.pkl
# train_0:, 1200, val_0:, 150, test_0:, 150, train_1:, 1200, val_1:, 150, test_1:, 150, train_2:, 1200, val_2:, 150, test_2:, 150, class 5 is added as ukc
# ukc_5:, 150
# length of train_data - (num_seq_per_cls * num_class)// batch size: 112
# get_bgdata  num_classses: 3 and self.num_classes: 3

# %%
# res = oset.ptmodel_custom_train(train_data=train_data, val_data=val_data,
#                  test_data=test_data, bglog=bglog, 
#                  manual_color_map=True, centroid_black=True,                               
#                  tsne_n_iter=2000, tsne_perplexity=8,
#                  embedding_size=12, oc_lr=2.5, pt_epochs=5, oc_epochs=2,
#                 save_ptmodel=False, save_ocmodel=False, oc_centroid_plot=False,
#                                halpha=0.7, hbeta=1.5, batch_normalize=True )


res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, 
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.8, hbeta=1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=False, pt_epochs=10,
                oc_lr=0.04, oc_epochs=10, oc_wait=5, oc_centroid_plot=False,
                save_ocmodel=False,)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# extracting all the values from your input parameter
# vocab_size: 50
# 2022-05-11 13:27:21.972940
# starting to create ptmodel automatically
# epoch: 1/5, train_loss: 3.536689519882202, train_acc: 54.55, F1_train: 0.4397 val_loss: 3.536689519882202, val_acc: 59.38,, F1_val: 0.4985
# epoch: 2/5, train_loss: 2.601609230041504, train_acc: 53.54, F1_train: 0.4291 val_loss: 2.601609230041504, val_acc: 62.5,, F1_val: 0.517
# epoch: 3/5, train_loss: 2.26823353767395, train_acc: 67.52, F1_train: 0.6744 val_loss: 2.26823353767395, val_acc: 94.64,, F1_val: 0.9451
# epoch: 4/5, train_loss: 1.9935120344161987, train_acc: 73.74, F1_train: 0.736 val_loss: 1.9935120344161987, val_acc: 96.21,, F1_val: 0.9616
# epoch: 5/5, train_loss: 1.633000135421753, train_acc: 84.38, F1_train: 0.8405 val_loss: 1.633000135421753, val_acc: 99.78,, F1_val: 0.9978
# run_id:  2022-05-11_13_28_15.971336_1d143c54d10011ec8594ac8247733f47
# ...

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, 
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.8, hbeta=1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=False, pt_epochs=10,
                oc_lr=0.1, oc_epochs=20, oc_wait=5, oc_centroid_plot=False,
                save_ocmodel=False,)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.56it/s]
# epoch: 1/20, train_loss: 0.3363148272037506, F1_train: 0.47548697928306705 F1_val: 0.5821745482365915
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.53it/s]
# epoch: 2/20, train_loss: 0.33618682622909546, F1_train: 0.49981237349142227 F1_val: 0.593467484634718
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# epoch: 3/20, train_loss: 0.33587056398391724, F1_train: 0.5125597056159855 F1_val: 0.6038477149527693
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# ...

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, 
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.8, hbeta=1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=False, pt_epochs=10,
                oc_lr=0.2, oc_epochs=30, oc_wait=5, oc_centroid_plot=False,
                save_ocmodel=False,)
oset.radius
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.41it/s]
# epoch: 1/30, train_loss: 0.33149343729019165, F1_train: 0.7292826780753768 F1_val: 0.9506002161961996
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.41it/s]
# epoch: 2/30, train_loss: 0.3312376141548157, F1_train: 0.7344853066335473 F1_val: 0.9570254298799216
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.35it/s]
# epoch: 3/30, train_loss: 0.3315914273262024, F1_train: 0.7463790280313268 F1_val: 0.960842762349485
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.32it/s]
# ...

# %%
oset.radius
# Out:
# <tf.Variable 'boundary_loss_5/Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[0.980405  ],
#        [0.96225345],
#        [0.94677246]], dtype=float32)>

# %%
oset.radius_changes
# Out:
# [<tf.Variable 'boundary_loss/Variable:0' shape=(3, 1) dtype=float32, numpy=
#  array([[0.72645944],
#         [0.76287174],
#         [0.7312454 ]], dtype=float32)>,
#  <tf.Variable 'boundary_loss/Variable:0' shape=(3, 1) dtype=float32, numpy=
#  array([[0.73058045],
#         [0.7669909 ],
#         [0.7353645 ]], dtype=float32)>,
#  <tf.Variable 'boundary_loss/Variable:0' shape=(3, 1) dtype=float32, numpy=
#  array([[0.7452729],
#         [0.7816855],
#         [0.7500591]], dtype=float32)>,
#  <tf.Variable 'boundary_loss/Variable:0' shape=(3, 1) dtype=float32, numpy=
#  array([[0.76203156],
#         [0.79844546],
#         [0.76681733]], dtype=float32)>,
#  <tf.Variable 'boundary_loss/Variable:0' shape=(3, 1) dtype=float32, numpy=
#  array([[0.76564986],
#         [0.80206364],
#         [0.77043486]], dtype=float32)>,
#  <tf.Variable 'boundary_loss/Variable:0' shape=(3, 1) dtype=float32, numpy=
#  array([[0.7737604 ],
#         [0.8101702 ],
# ...

# %%
oset.best_train_score
# Out:
# 0.49381571517558553
