# %%
import os, sys
cur_dir = os.getcwd()
basename = os.path.basename(cur_dir)
for _ in range(5):
    if basename != 'OCLog':
        cur_dir = os.path.dirname(cur_dir)
        basename = os.path.basename(cur_dir)
        #print(cur_dir, basename)
    else:
        if cur_dir not in sys.path:
            sys.path.append(cur_dir)
            #print(sys.path)
import os
from openpyxl import Workbook
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tqdm import trange, tqdm, tnrange
from oclog.BGL.bglv1 import BGLog
from oclog.openset.opensetv13 import OpenSet
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
import sklearn.metrics as m
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.manifold import TSNE
tf.random.set_seed(1234)
np.random.seed(1234) 
# tf.random.set_seed(1234)
# np.random.seed(1234)

# %%
oset = OpenSet()
train_data, val_data,  test_data, bglog  = oset.get_bgdata(bg_class_obj=BGLog, save_padded_num_sequences=False, 
                                                           load_from_pkl=True, ablation=1500,
                                                           debug=False,
                                                          designated_ukc_cls=5)
# Out:
# extracting all the values from your input parameter
# padded_num_seq_df loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc.pkl
# trained tokenizer, tk, loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_tk.pkl
# train_0:, 1200, val_0:, 150, test_0:, 150, train_1:, 1200, val_1:, 150, test_1:, 150, train_2:, 1200, val_2:, 150, test_2:, 150, class 5 is added as ukc
# ukc_5:, 150
# length of train_data - (num_seq_per_cls * num_class)// batch size: 112
# get_bgdata  num_classses: 3 and self.num_classes: 3

# %%
# res = oset.ptmodel_custom_train(train_data=train_data, val_data=val_data,
#                  test_data=test_data, bglog=bglog, 
#                  manual_color_map=True, centroid_black=True,                               
#                  tsne_n_iter=2000, tsne_perplexity=8,
#                  embedding_size=12, oc_lr=2.5, pt_epochs=5, oc_epochs=2,
#                 save_ptmodel=False, save_ocmodel=False, oc_centroid_plot=False,
#                                halpha=0.7, hbeta=1.5, batch_normalize=True )
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=5,
                oc_lr=0.18, oc_epochs=5, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# extracting all the values from your input parameter
# vocab_size: 50
# 2022-05-11 17:11:07.843157
# starting to create ptmodel automatically
# epoch: 1/5, train_loss: 3.846605062484741, train_acc: 52.26, F1_train: 0.4253 val_loss: 3.846605062484741, val_acc: 59.38,, F1_val: 0.4985
# epoch: 2/5, train_loss: 2.8630712032318115, train_acc: 50.95, F1_train: 0.4073 val_loss: 2.8630712032318115, val_acc: 61.61,, F1_val: 0.5088
# epoch: 3/5, train_loss: 2.4504919052124023, train_acc: 62.28, F1_train: 0.6216 val_loss: 2.4504919052124023, val_acc: 91.29,, F1_val: 0.9095
# epoch: 4/5, train_loss: 2.0752928256988525, train_acc: 56.67, F1_train: 0.5141 val_loss: 2.0752928256988525, val_acc: 63.84,, F1_val: 0.5386
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# epoch: 5/5, train_loss: 1.730332851409912, train_acc: 87.5, F1_train: 0.8739 val_loss: 1.730332851409912, val_acc: 99.55,, F1_val: 0.9955
# run_id:  2022-05-11_17_12_01.616164_5f630f6ad11f11ec8594ac8247733f47
# got all the dataset
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
# run_id:  2022-05-11_17_12_21.560925_6b4663a9d11f11ecb136ac8247733f47
# unknown optimizer None. assigning default as adam with lr_rate=0.18
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.59it/s]
# epoch: 1/5, train_loss: 0.27499455213546753, F1_train: 0.8420848961938504 F1_val: 0.9539395081244025,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.57it/s]
# epoch: 2/5, train_loss: 0.27520835399627686, F1_train: 0.859607270944246 F1_val: 0.9615426761505554,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 3/5, train_loss: 0.27517107129096985, F1_train: 0.8709124866510157 F1_val: 0.9730539616149337,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 4/5, train_loss: 0.27519580721855164, F1_train: 0.05129652585241627 F1_val: 0.045709793351302784,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.55it/s]
# epoch: 5/5, train_loss: 0.2749934792518616, F1_train: 0.6175718973240264 F1_val: 0.6431700645932273,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# Best readius assigned as [[0.99250305]
#  [1.0289004 ]
#  [0.9972877 ]]
# classification report for training:
# [[1100    5    1   89]
#  [ 124  761    0  310]
#  [   5    0 1041  148]
#  [   0    0    0    0]]
# 80.97
# f1_weighted: 0.8716008613702365, f1_macro: 0.6537130991973744, f1_micro: 0.8097098214285714, f_measure: {'Known': 87.1617, 'Open': 0, 'F1-score': 65.3713}
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1195
#            1       0.99      0.64      0.78      1195
#            2       1.00      0.87      0.93      1194
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.81      3584
#    macro avg       0.72      0.61      0.65      3584
# weighted avg       0.96      0.81      0.87      3584
#
# classification report for test data:
# [[138   2   0   2]
#  [  0 147   0   0]
#  [  0   0  82  62]
#  [ 23   1   5 114]]
# 83.51
# f1_weighted: 0.8310165726741788, f1_macro: 0.8302567906990966, f1_micro: 0.8350694444444444, f_measure: {'Known': 87.0249, 'Open': 71.028, 'F1-score': 83.0257}
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       142
#            1       0.98      1.00      0.99       147
#            2       0.94      0.57      0.71       144
#            5       0.64      0.80      0.71       143
#
#     accuracy                           0.84       576
#    macro avg       0.86      0.83      0.83       576
# weighted avg       0.86      0.84      0.83       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.7, hbeta=1.2, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=5,
                oc_lr=0.08, oc_epochs=10, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.08
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.46it/s]
# epoch: 1/10, train_loss: 0.27922356128692627, F1_train: 0.78920247474592 F1_val: 0.9241917225941982,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.19it/s]
# epoch: 2/10, train_loss: 0.2785777449607849, F1_train: 0.5933533283344538 F1_val: 0.6037645564767337,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.29it/s]
# epoch: 3/10, train_loss: 0.27891847491264343, F1_train: 0.5997097803145515 F1_val: 0.6102003751223738,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.43it/s]
# epoch: 4/10, train_loss: 0.27905136346817017, F1_train: 0.5882371963419308 F1_val: 0.61156306272509,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.41it/s]
# epoch: 5/10, train_loss: 0.27950242161750793, F1_train: 0.8310509620199829 F1_val: 0.9453963112532018,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 6/10, train_loss: 0.2787344455718994, F1_train: 0.8362664187866934 F1_val: 0.9490952144870055,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.50it/s]
# epoch: 7/10, train_loss: 0.2787456214427948, F1_train: 0.597024956840886 F1_val: 0.6165301134051134,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.47it/s]
# epoch: 8/10, train_loss: 0.2791171967983246, F1_train: 0.8429983532648464 F1_val: 0.9491378417564208,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.43it/s]
# epoch: 9/10, train_loss: 0.27906280755996704, F1_train: 0.8448417864273495 F1_val: 0.9491140127803861,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.52it/s]
# epoch: 10/10, train_loss: 0.2786024212837219, F1_train: 0.8444856044738354 F1_val: 0.9529129052451238,
# Best readius assigned as [[0.86250556]
#  [0.93294126]
#  [0.8731528 ]]
# classification report for training:
# [[1032    4    1  158]
#  [  56  713    0  427]
#  [   0    0  943  250]
#  [   0    0    0    0]]
# 75.0
# f1_weighted: 0.8439660719763784, f1_macro: 0.6330113111255953, f1_micro: 0.75, f_measure: {'Known': 84.4015, 'Open': 0, 'F1-score': 63.3011}
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90      1195
#            1       0.99      0.60      0.75      1196
#            2       1.00      0.79      0.88      1193
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.75      3584
#    macro avg       0.74      0.56      0.63      3584
# weighted avg       0.98      0.75      0.84      3584
#
# classification report for test data:
# [[128   1   0  16]
#  [  0 142   0   0]
#  [  0   0  69  76]
#  [ 12   0   3 129]]
# 81.25
# f1_weighted: 0.8085862002738471, f1_macro: 0.8093827144086465, f1_micro: 0.8125, f_measure: {'Known': 84.3561, 'Open': 70.6849, 'F1-score': 80.9383}
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       145
#            1       0.99      1.00      1.00       142
#            2       0.96      0.48      0.64       145
#            5       0.58      0.90      0.71       144
#
#     accuracy                           0.81       576
#    macro avg       0.86      0.81      0.81       576
# weighted avg       0.86      0.81      0.81       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
oset = OpenSet()
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.9, hbeta=0.1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=5,
                oc_lr=0.08, oc_epochs=10, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# extracting all the values from your input parameter
# vocab_size: 50
# 2022-05-11 17:29:15.198280
# starting to create ptmodel automatically
# epoch: 1/5, train_loss: 1.6031941175460815, train_acc: 56.61, F1_train: 0.4546 val_loss: 1.6031941175460815, val_acc: 64.06,, F1_val: 0.5361
# epoch: 2/5, train_loss: 0.8409387469291687, train_acc: 72.57, F1_train: 0.7112 val_loss: 0.8409387469291687, val_acc: 99.78,, F1_val: 0.9978
# epoch: 3/5, train_loss: 0.6949641704559326, train_acc: 77.62, F1_train: 0.7604 val_loss: 0.6949641704559326, val_acc: 99.78,, F1_val: 0.9978
# epoch: 4/5, train_loss: 0.5952305197715759, train_acc: 89.48, F1_train: 0.892 val_loss: 0.5952305197715759, val_acc: 100.0,, F1_val: 1.0
# epoch: 5/5, train_loss: 0.5337111949920654, train_acc: 93.19, F1_train: 0.9313 val_loss: 0.5337111949920654, val_acc: 99.78,, F1_val: 0.9978
# run_id:  2022-05-11_17_30_09.019945_e787b59dd12111ecb47dac8247733f47
# got all the dataset
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
# run_id:  2022-05-11_17_30_28.315347_f307f440d12111ec8549ac8247733f47
# unknown optimizer None. assigning default as adam with lr_rate=0.08
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.58it/s]
# epoch: 1/10, train_loss: 1.169726014137268, F1_train: 0.10243086381392044 F1_val: 0.16741071428571427,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.66it/s]
# epoch: 2/10, train_loss: 1.1708990335464478, F1_train: 0.11611773858921161 F1_val: 0.1860263522884882,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.62it/s]
# epoch: 3/10, train_loss: 1.1716948747634888, F1_train: 0.12937689611573122 F1_val: 0.19806338028169015,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# epoch: 4/10, train_loss: 1.1703392267227173, F1_train: 0.13683502223347985 F1_val: 0.2088794233289646,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 5/10, train_loss: 1.170517921447754, F1_train: 0.14551813440921008 F1_val: 0.21261415525114155,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# epoch: 6/10, train_loss: 1.1710326671600342, F1_train: 0.15095596934984715 F1_val: 0.2182449903038138,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.35it/s]
# epoch: 7/10, train_loss: 1.1704380512237549, F1_train: 0.15586758815551782 F1_val: 0.22073190262652148,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.36it/s]
# epoch: 8/10, train_loss: 1.1715422868728638, F1_train: 0.1617374148947089 F1_val: 0.2323767935121647,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.21it/s]
# epoch: 9/10, train_loss: 1.1716907024383545, F1_train: 0.1646073864993702 F1_val: 0.23480983302411876,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.53it/s]
# epoch: 10/10, train_loss: 1.171202540397644, F1_train: 0.16814159984375165 F1_val: 0.23854230533415086,
# Best readius assigned as [[0.89604586]
#  [0.9324603 ]
#  [0.9008337 ]]
# classification report for training:
# [[ 399    0    0  796]
#  [   0    1    0 1196]
#  [   0    0    0 1192]
#  [   0    0    0    0]]
# 11.16
# f1_weighted: 0.16747991542260943, f1_macro: 0.12557420041348713, f1_micro: 0.11160714285714286, f_measure: {'Known': 16.7432, 'Open': 0, 'F1-score': 12.5574}
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50      1195
#            1       1.00      0.00      0.00      1197
#            2       0.00      0.00      0.00      1192
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.11      3584
#    macro avg       0.50      0.08      0.13      3584
# weighted avg       0.67      0.11      0.17      3584
#
# classification report for test data:
# [[ 64   0   0  80]
#  [  0   0   0 142]
#  [  0   0   0 147]
#  [  2   0   0 141]]
# 35.59
# f1_weighted: 0.2595944541675782, f1_macro: 0.26034419893531685, f1_micro: 0.35590277777777785, f_measure: {'Known': 20.3175, 'Open': 43.1853, 'F1-score': 26.0344}
#               precision    recall  f1-score   support
#
#            0       0.97      0.44      0.61       144
#            1       0.00      0.00      0.00       142
#            2       0.00      0.00      0.00       147
#            5       0.28      0.99      0.43       143
#
#     accuracy                           0.36       576
#    macro avg       0.31      0.36      0.26       576
# weighted avg       0.31      0.36      0.26       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
oset = OpenSet()
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.9, hbeta=0.1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=5,
                oc_lr=0.16, oc_epochs=10, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# extracting all the values from your input parameter
# vocab_size: 50
# 2022-05-11 17:34:48.528045
# starting to create ptmodel automatically
# epoch: 1/5, train_loss: 1.60175621509552, train_acc: 55.33, F1_train: 0.444 val_loss: 1.60175621509552, val_acc: 62.05,, F1_val: 0.5214
# epoch: 2/5, train_loss: 0.8851045370101929, train_acc: 57.11, F1_train: 0.4575 val_loss: 0.8851045370101929, val_acc: 66.07,, F1_val: 0.5514
# epoch: 3/5, train_loss: 0.6918870806694031, train_acc: 76.65, F1_train: 0.7541 val_loss: 0.6918870806694031, val_acc: 99.55,, F1_val: 0.9955
# epoch: 4/5, train_loss: 0.6002888083457947, train_acc: 88.39, F1_train: 0.8795 val_loss: 0.6002888083457947, val_acc: 100.0,, F1_val: 1.0
# epoch: 5/5, train_loss: 0.520315408706665, train_acc: 94.2, F1_train: 0.9412 val_loss: 0.520315408706665, val_acc: 100.0,, F1_val: 1.0
# run_id:  2022-05-11_17_35_42.424572_ae4137e0d12211ec9ef6ac8247733f47
# got all the dataset
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
# run_id:  2022-05-11_17_36_02.457325_ba31f94ad12211ecbec3ac8247733f47
# unknown optimizer None. assigning default as adam with lr_rate=0.16
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.08it/s]
# epoch: 1/10, train_loss: 1.206750750541687, F1_train: 0.1997522735677424 F1_val: 0.2606413994169096,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.44it/s]
# epoch: 2/10, train_loss: 1.2043850421905518, F1_train: 0.2215862121467981 F1_val: 0.28625954198473286,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.32it/s]
# epoch: 3/10, train_loss: 1.2057037353515625, F1_train: 0.2370647986296477 F1_val: 0.29899182920400635,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.52it/s]
# epoch: 4/10, train_loss: 1.2052383422851562, F1_train: 0.2451460152547906 F1_val: 0.30383211678832117,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.36it/s]
# epoch: 5/10, train_loss: 1.2063912153244019, F1_train: 0.2519625183169319 F1_val: 0.308967112024666,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.50it/s]
# epoch: 6/10, train_loss: 1.20553719997406, F1_train: 0.2556136097073975 F1_val: 0.31470848056537104,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 7/10, train_loss: 1.2051740884780884, F1_train: 0.25740885969382016 F1_val: 0.3137189716312056,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 8/10, train_loss: 1.2067325115203857, F1_train: 0.26072063100400417 F1_val: 0.3149608783442706,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.45it/s]
# epoch: 9/10, train_loss: 1.2060191631317139, F1_train: 0.26321375525498336 F1_val: 0.3184315684315684,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 10/10, train_loss: 1.2063207626342773, F1_train: 0.26471806811633686 F1_val: 0.3161940392354125,
# Best readius assigned as [[1.1037216]
#  [1.1401362]
#  [1.1085092]]
# classification report for training:
# [[ 758    0    0  437]
#  [   5    5    0 1186]
#  [   0    0    5 1188]
#  [   0    0    0    0]]
# 21.43
# f1_weighted: 0.26371558946920143, f1_macro: 0.19773327212421854, f1_micro: 0.21428571428571427, f_measure: {'Known': 26.3644, 'Open': 0, 'F1-score': 19.7733}
#               precision    recall  f1-score   support
#
#            0       0.99      0.63      0.77      1195
#            1       1.00      0.00      0.01      1196
#            2       1.00      0.00      0.01      1193
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.21      3584
#    macro avg       0.75      0.16      0.20      3584
# weighted avg       1.00      0.21      0.26      3584
#
# classification report for test data:
# [[123   0   0  22]
#  [  0   0   0 142]
#  [  0   0   0 144]
#  [ 13   0   0 132]]
# 44.27
# f1_weighted: 0.3339850680820431, f1_macro: 0.33168172278492564, f1_micro: 0.4427083333333333, f_measure: {'Known': 29.1815, 'Open': 45.1282, 'F1-score': 33.1682}
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       145
#            1       0.00      0.00      0.00       142
#            2       0.00      0.00      0.00       144
#            5       0.30      0.91      0.45       145
#
#     accuracy                           0.44       576
#    macro avg       0.30      0.44      0.33       576
# weighted avg       0.30      0.44      0.33       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.9, hbeta=0.1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=5,
                oc_lr=2, oc_epochs=10, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.51it/s]
# epoch: 1/10, train_loss: 1.2245094776153564, F1_train: 0.8730680101530977 F1_val: 0.9734892598343686,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# epoch: 2/10, train_loss: 1.2246010303497314, F1_train: 0.8906937853871061 F1_val: 0.9887313512223361,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.52it/s]
# epoch: 3/10, train_loss: 1.2255908250808716, F1_train: 0.8908866751451063 F1_val: 0.988792211086224,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.49it/s]
# epoch: 4/10, train_loss: 1.2248681783676147, F1_train: 0.8908690125036612 F1_val: 0.9887920893655675,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.53it/s]
# epoch: 5/10, train_loss: 1.2264255285263062, F1_train: 0.8911156312688426 F1_val: 0.9887929552487135,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.53it/s]
# epoch: 6/10, train_loss: 1.2235783338546753, F1_train: 0.8908790248215502 F1_val: 0.9887929552487135,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.51it/s]
# epoch: 7/10, train_loss: 1.2259231805801392, F1_train: 0.8911705775120868 F1_val: 0.9887920893655675,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.52it/s]
# epoch: 8/10, train_loss: 1.226232647895813, F1_train: 0.8908916929644205 F1_val: 0.9887920893655675,
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.53it/s]
# epoch: 9/10, train_loss: 1.2236521244049072, F1_train: 0.8903350901239678 F1_val: 0.9887920893655675,
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# epoch: 10/10, train_loss: 1.224732518196106, F1_train: 0.890894360127027 F1_val: 0.9887929552487135,
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# Best readius assigned as [[5.341017]
#  [5.349731]
#  [5.335709]]
# classification report for training:
# [[1191    1    0]
#  [ 271  916    7]
#  [  69   44 1085]]
# 89.06
# f1_weighted: 0.8909005656265304, f1_macro: 0.8908282454326826, f1_micro: 0.890625, f_measure: {'Known': 86.2443, 'Open': 94.7598, 'F1-score': 89.0828}
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.87      1192
#            1       0.95      0.77      0.85      1194
#            2       0.99      0.91      0.95      1198
#
#     accuracy                           0.89      3584
#    macro avg       0.91      0.89      0.89      3584
# weighted avg       0.91      0.89      0.89      3584
#
# classification report for test data:
# [[145   0   0   0]
#  [  0 147   0   0]
#  [ 36  21  84   0]
#  [128  10   5   0]]
# 65.28
# f1_weighted: 0.5704703320498905, f1_macro: 0.5684541717619671, f1_micro: 0.6527777777777778, f_measure: {'Known': 75.7939, 'Open': 0, 'F1-score': 56.8454}
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64       145
#            1       0.83      1.00      0.90       147
#            2       0.94      0.60      0.73       141
#            5       0.00      0.00      0.00       143
#
#     accuracy                           0.65       576
#    macro avg       0.56      0.65      0.57       576
# weighted avg       0.56      0.65      0.57       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']

# %%
res = oset.train(train_data=train_data, val_data=val_data, test_data=test_data, bglog=bglog, designated_ukc_cls=5,
                 manual_color_map=True, centroid_black=True,tsne_n_iter=2000, tsne_perplexity=8,
                 embedding_size=12, save_ptmodel=False, halpha=0.9, hbeta=0.1, batch_normalize=True, ptmodel_vhm=True,
                plot_ptmodel_centroid=True, pt_epochs=5,
                oc_lr=.32, oc_epochs=10, oc_wait=5, oc_centroid_plot=True,
                save_ocmodel=False, pt_retrain=False)
# Out:
# extracting all the values from your input parameter
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=0.32
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.50it/s]
# epoch: 1/10, train_loss: 1.223042607307434, F1_train: 0.2428507829811583 F1_val: 0.30477272727272725,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.39it/s]
# epoch: 2/10, train_loss: 1.2241212129592896, F1_train: 0.2658668134565158 F1_val: 0.3161940392354125,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.48it/s]
# epoch: 3/10, train_loss: 1.2219171524047852, F1_train: 0.28024989342443896 F1_val: 0.3245888561610211,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.38it/s]
# epoch: 4/10, train_loss: 1.223417043685913, F1_train: 0.2878425573560755 F1_val: 0.3291464891041162,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.50it/s]
# epoch: 5/10, train_loss: 1.222844123840332, F1_train: 0.2958938656958682 F1_val: 0.32697464651389563,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:15<00:00,  7.29it/s]
# epoch: 6/10, train_loss: 1.2225943803787231, F1_train: 0.3116098397533912 F1_val: 0.3445997085702968,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.51it/s]
# epoch: 7/10, train_loss: 1.2206286191940308, F1_train: 0.31970657974829936 F1_val: 0.34998260667903525,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.54it/s]
# epoch: 8/10, train_loss: 1.2215098142623901, F1_train: 0.3282127220686467 F1_val: 0.34998260667903525,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.51it/s]
# epoch: 9/10, train_loss: 1.2222319841384888, F1_train: 0.3321413704364566 F1_val: 0.34998260667903525,
# 100%|████████████████████████████████████████████████████████████████████████████████| 112/112 [00:14<00:00,  7.53it/s]
# epoch: 10/10, train_loss: 1.223232626914978, F1_train: 0.335368594652904 F1_val: 0.3522117180205416,
# Best readius assigned as [[1.4855331]
#  [1.5559703]
#  [1.4961851]]
# classification report for training:
# [[ 847    0    0  345]
#  [  21   28    0 1146]
#  [   0    0   89 1108]
#  [   0    0    0    0]]
# 26.9
# f1_weighted: 0.334993461069841, f1_macro: 0.25163320656775673, f1_micro: 0.2689732142857143, f_measure: {'Known': 33.5511, 'Open': 0, 'F1-score': 25.1633}
#               precision    recall  f1-score   support
#
#            0       0.98      0.71      0.82      1192
#            1       1.00      0.02      0.05      1195
#            2       1.00      0.07      0.14      1197
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.27      3584
#    macro avg       0.74      0.20      0.25      3584
# weighted avg       0.99      0.27      0.33      3584
#
# classification report for test data:
# [[144   0   0   1]
#  [  0   0   0 143]
#  [  0   0   0 146]
#  [ 22   0   0 120]]
# 45.83
# f1_weighted: 0.3403049613992575, f1_macro: 0.34020690619320565, f1_micro: 0.4583333333333333, f_measure: {'Known': 30.8682, 'Open': 43.4783, 'F1-score': 34.0207}
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       145
#            1       0.00      0.00      0.00       143
#            2       0.00      0.00      0.00       146
#            5       0.29      0.85      0.43       142
#
#     accuracy                           0.46       576
#    macro avg       0.29      0.46      0.34       576
# weighted avg       0.29      0.46      0.34       576
#
# plotting feature map with UKC
# the color map for the classes, here index postion are the class number: ['green' 'blue' 'yellow' 'red']
