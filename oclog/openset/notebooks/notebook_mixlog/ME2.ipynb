# %%
import os, sys
cur_dir = os.getcwd()
basename = os.path.basename(cur_dir)
for _ in range(5):
    if basename != 'OCLog':
        cur_dir = os.path.dirname(cur_dir)
        basename = os.path.basename(cur_dir)
        #print(cur_dir, basename)
    else:
        if cur_dir not in sys.path:
            sys.path.append(cur_dir)
            #print(sys.path)
sys.path.append('C:\\Users\\Bhujay_ROG\\MyDev\\OCLog\\oclog\hdfs')
##### appending the static path to aavoid the error 
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       2 hdfs_obj_full_name_path = 'C:\\Users\\Bhujay_ROG\\MyDev\\OCLog\\oclog\\hdfs\\data\\hdfsobj_32_64_no_meta.pkl'
#       3 with open(hdfs_obj_full_name_path, 'rb') as f:
# ----> 4             hdfslogs = pickle.load(f)

# ModuleNotFoundError: No module named 'hdflogv3'
from oclog.BGL.multilogv1 import MixedLog, get_embedding_layer
from oclog.hdfs.hdflogv3 import HDFSLogv3
import numpy as np
import pandas as pd
from oclog.openset.opensetv11 import OpenSet
from tensorflow.keras.utils import to_categorical
from sklearn import preprocessing

# %%
mlog = MixedLog(debug=True,
                mixed_logs=True,
                padded_seq_len=32, 
                padded_char_len=176, 
                log_meta_status='time_ip',                
                save_padded_num_sequences=True,
                load_from_pkl=False, )
res = mlog.get_mix_log_df(hdfs_selected_cls='hdfs_normal')
# Out:
# saved file name will be:  bgl_ukc_32_176_time_ip
# ############## you want to mix log from HDFS, let me try that #####################
# #### I will change the existing label of BGL to accomodate hdfs label #####
# saved file name will be:  bgl_ukc_32_176_time_ip
# padded_num_seq_df loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc_32_176_time_ip.pkl
# trained tokenizer, tk, loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc_32_176_time_ip_tk.pkl
# taking few selected classes from original bgl:  {'0': 114115, '1': 28439}
# changed bgl classes:  {'0': 114115, '1': 28439}
# found existing hdfs saved object from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\hdfs\data\hdfsobj_32_176_time_ip.pkl
# classes in hdfs df, lebeled_num_seq_df_epn:
#  {'hdfs_anomaly': 16838, 'hdfs_normal': 16838}
# hdfs class map:  {'hdfs_normal': '2', 'hdfs_anomaly': '3'}
# changed hdfs classes:  {'3': 16838, '2': 16838}
# taking only 2 as per parameter hdfs_selected_cls=hdfs_normal
# Merged the bgl and hdfs level as the mixed df:  {'0': 114115, '1': 28439, '2': 16838}

# %%
train_test = mlog.get_tensor_train_val_test(ablation=2000, designated_ukc_cls=2 , hdfs_selected_cls='hdfs_normal')
train_data, val_data, test_data = train_test
oset = OpenSet()
res = oset.train(bglog=mlog, train_data=train_data, val_data=val_data, test_data=test_data, 
                 pt_epochs=16, oc_epochs=50, oc_lr=2.5, embedding_size=26, oc_wait=8,
                manual_color_map=True, centroid_black=False, pt_early_stop=False),
# Out:
# ablation set to : 2000
# parameter value for designated_ukc_cls within multiclass:  2
# ############## you want to mix log from HDFS, let me try that #####################
# #### I will change the existing label of BGL to accomodate hdfs label #####
# saved file name will be:  bgl_ukc_32_176_time_ip
# padded_num_seq_df loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc_32_176_time_ip.pkl
# trained tokenizer, tk, loaded from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\BGL\data\bgl_ukc_32_176_time_ip_tk.pkl
# taking few selected classes from original bgl:  {'0': 114115, '1': 28439}
# changed bgl classes:  {'0': 114115, '1': 28439}
# found existing hdfs saved object from C:\Users\Bhujay_ROG\MyDev\OCLog\oclog\hdfs\data\hdfsobj_32_176_time_ip.pkl
# classes in hdfs df, lebeled_num_seq_df_epn:
#  {'hdfs_anomaly': 16838, 'hdfs_normal': 16838}
# hdfs class map:  {'hdfs_normal': '2', 'hdfs_anomaly': '3'}
# changed hdfs classes:  {'3': 16838, '2': 16838}
# taking only 2 as per parameter hdfs_selected_cls=hdfs_normal
# Merged the bgl and hdfs level as the mixed df:  {'0': 114115, '1': 28439, '2': 16838}
# class_0 not a desgnated ukc, hence adding in train, val and test
# train_0:, 1600
# val_0:, 200
# test_0:, 200
# class_1 not a desgnated ukc, hence adding in train, val and test
# train_1:, 1600
# val_1:, 200
# test_1:, 200
# class 2 is added as ukc
# ukc_2:, 200
# class_3 not a desgnated ukc, hence adding in train, val and test
# 0 data in class 3 not enough to split into train:1600 and validation:200, adding the entire data as temp  ukc bucket from where later actual ukc can be taken
# ukc_3:, 0
# total data in  temp ukc bucket: 200
# you wanted 1000 ukc data but that much is not there.  adding 200 to ukc data
# ukc_to_add df :  {'2': 200}
# train classes: {'0': 1600, '1': 1600}
# val classes: {'0': 200, '1': 200}
# test classes: {'0': 200, '1': 200, '2': 200}
# test df {'0': 200, '1': 200, '2': 200}
# some example of labels:
# first two train label [[1. 0.]
#  [1. 0.]]
# first two test label [[1. 0. 0.]
#  [1. 0. 0.]]
# train_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32, 2), dtype=tf.float32, name=None))>
# val_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32, 2), dtype=tf.float32, name=None))>
# test_data <BatchDataset element_spec=(TensorSpec(shape=(32, 32, 176), dtype=tf.int32, name=None), TensorSpec(shape=(32, 3), dtype=tf.float32, name=None))>
# char in lines, train_data.element_spec[0].shape[2] 176
# num classes, train_data.element_spec[1].shape[1]:  2
# length of val_data: 12
# length of train_data - (num_seq_per_cls * num_class)// batch size: 100
# got all the dataset
# unknown optimizer None. assigning default as adam with lr_rate=2.5
# got all the dataset
# got all the dataset
# vocab_size: 50
# got all the dataset
# 2022-05-01 16:02:56.080593
# starting to create ptmodel automatically
# staring pre trining
# Epoch 1/16
# 100/100 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9572 - precision_2: 0.9572 - recall_2: 0.9572
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to data\ptmodel_2022-05-01_16_02_56.080593\
# INFO:tensorflow:Assets written to: data\ptmodel_2022-05-01_16_02_56.080593\assets
# 100/100 [==============================] - 28s 276ms/step - loss: 0.0933 - accuracy: 0.9572 - precision_2: 0.9572 - recall_2: 0.9572 - val_loss: 6.2674e-04 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 0.0010
# Epoch 2/16
# 100/100 [==============================] - ETA: 0s - loss: 2.8614e-04 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 2: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 259ms/step - loss: 2.8614e-04 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 1.8392e-04 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 0.0010
# Epoch 3/16
# 100/100 [==============================] - ETA: 0s - loss: 1.1536e-04 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 3: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 260ms/step - loss: 1.1536e-04 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 1.1209e-04 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 0.0010
# Epoch 4/16
# 100/100 [==============================] - ETA: 0s - loss: 6.3752e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 4: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 260ms/step - loss: 6.3752e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 8.0443e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 5.0000e-04
# Epoch 5/16
# 100/100 [==============================] - ETA: 0s - loss: 4.8397e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 5: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 256ms/step - loss: 4.8397e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 6.1813e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 5.0000e-04
# Epoch 6/16
# 100/100 [==============================] - ETA: 0s - loss: 3.8700e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 6: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 256ms/step - loss: 3.8700e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 5.0917e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 2.5000e-04
# Epoch 7/16
# 100/100 [==============================] - ETA: 0s - loss: 3.4145e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 7: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 3.4145e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 5.0678e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 2.5000e-04
# Epoch 8/16
# 100/100 [==============================] - ETA: 0s - loss: 3.0609e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 8: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 3.0609e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 4.7028e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 1.2500e-04
# Epoch 9/16
# 100/100 [==============================] - ETA: 0s - loss: 2.8636e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 9: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 2.8636e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 4.3936e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 1.2500e-04
# Epoch 10/16
# 100/100 [==============================] - ETA: 0s - loss: 2.7109e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 10: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 258ms/step - loss: 2.7109e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 4.2991e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 6.2500e-05
# Epoch 11/16
# 100/100 [==============================] - ETA: 0s - loss: 2.6105e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 11: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 11: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 256ms/step - loss: 2.6105e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 4.2342e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 6.2500e-05
# Epoch 12/16
# 100/100 [==============================] - ETA: 0s - loss: 2.5319e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 12: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 2.5319e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 4.1413e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 3.1250e-05
# Epoch 13/16
# 100/100 [==============================] - ETA: 0s - loss: 2.4835e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 13: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 2.4835e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 4.0436e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 3.1250e-05
# Epoch 14/16
# 100/100 [==============================] - ETA: 0s - loss: 2.4411e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 14: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 2.4411e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 3.9523e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 1.5625e-05
# Epoch 15/16
# 100/100 [==============================] - ETA: 0s - loss: 2.4132e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 15: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 15: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 257ms/step - loss: 2.4132e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 3.9631e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 1.5625e-05
# Epoch 16/16
# 100/100 [==============================] - ETA: 0s - loss: 2.3905e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 16: val_accuracy did not improve from 1.00000
# 100/100 [==============================] - 26s 258ms/step - loss: 2.3905e-05 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 3.9482e-05 - val_accuracy: 1.0000 - val_precision_2: 1.0000 - val_recall_2: 1.0000 - lr: 7.8125e-06
# run_id:  2022-05-01_16_09_51.302724_07d0e6a9c93b11ecb136ac8247733f47
# the color map for the classes, here index postion are the class number: ['green', 'blue', 'yellow', 'pink', 'black', 'orange', 'purple', 'red', 'beige', 'brown', 'gray', 'cyan', 'magenta']
# run_id:  2022-05-01_16_10_32.592371_206d337ec93b11ec9a10ac8247733f47
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.02it/s]
# epoch: 1/50, train_loss: 3.4349663257598877, F1_train: 0.49796046438657043 F1_val: 0.48956948138297873
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.01it/s]
# epoch: 2/50, train_loss: 3.4349639415740967, F1_train: 0.4996873045653534 F1_val: 0.4947916666666667
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.00it/s]
# epoch: 3/50, train_loss: 3.4349896907806396, F1_train: 0.5041996439070782 F1_val: 0.5078125
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.03it/s]
# epoch: 4/50, train_loss: 3.43498158454895, F1_train: 0.5153846153846154 F1_val: 0.5026041666666666
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.01it/s]
# epoch: 5/50, train_loss: 3.434985637664795, F1_train: 0.5751445086705202 F1_val: 0.5179875429553265
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.02it/s]
# epoch: 6/50, train_loss: 3.4349825382232666, F1_train: 0.770405836753306 F1_val: 0.6171875
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.02it/s]
# epoch: 7/50, train_loss: 3.4349520206451416, F1_train: 0.8824778077962177 F1_val: 0.9973821271929824
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 8/50, train_loss: 3.4349899291992188, F1_train: 0.888846447669977 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 9/50, train_loss: 3.434981346130371, F1_train: 0.8916349809885932 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.03it/s]
# epoch: 10/50, train_loss: 3.434978723526001, F1_train: 0.8937097385373248 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 11/50, train_loss: 3.434969186782837, F1_train: 0.8953136810279667 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.03it/s]
# epoch: 12/50, train_loss: 3.4349875450134277, F1_train: 0.895998489996225 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 13/50, train_loss: 3.434981346130371, F1_train: 0.8980436418359669 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 14/50, train_loss: 3.4349679946899414, F1_train: 0.8991738640630867 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.05it/s]
# epoch: 15/50, train_loss: 3.434973955154419, F1_train: 0.900749063670412 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  2.99it/s]
# epoch: 16/50, train_loss: 3.4349591732025146, F1_train: 0.9016454749439043 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:34<00:00,  2.90it/s]
# epoch: 17/50, train_loss: 3.4349753856658936, F1_train: 0.9027622247107129 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.00it/s]
# epoch: 18/50, train_loss: 3.434983015060425, F1_train: 0.9036526276556094 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  2.97it/s]
# epoch: 19/50, train_loss: 3.434971332550049, F1_train: 0.904096834264432 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.00it/s]
# epoch: 20/50, train_loss: 3.4349820613861084, F1_train: 0.9052044609665427 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.01it/s]
# epoch: 21/50, train_loss: 3.4349842071533203, F1_train: 0.9054254923820142 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  2.98it/s]
# epoch: 22/50, train_loss: 3.4349703788757324, F1_train: 0.9060876020786935 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.00it/s]
# epoch: 23/50, train_loss: 3.4349899291992188, F1_train: 0.9060876020786935 F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 24/50, train_loss: 3.434979200363159, F1_train: 0.9060876020786935 F1_val: 1.0
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.02it/s]
# epoch: 25/50, train_loss: 3.434985637664795, F1_train: 0.3695823483057525 F1_val: 0.22162208504801095
# train score not improving  going to wait state 3
# val score not improving  going to wait state 3
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  2.99it/s]
# epoch: 26/50, train_loss: 3.4349777698516846, F1_train: 0.9076268048870788 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  2.99it/s]
# epoch: 27/50, train_loss: 3.4349865913391113, F1_train: 0.9089397857406724 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:35<00:00,  2.85it/s]
# epoch: 28/50, train_loss: 3.434976816177368, F1_train: 0.9102469590858828 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.04it/s]
# epoch: 29/50, train_loss: 3.4349780082702637, F1_train: 0.9115483633688857 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.05it/s]
# epoch: 30/50, train_loss: 3.4349617958068848, F1_train: 0.9117647058823529 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.06it/s]
# epoch: 31/50, train_loss: 3.434974431991577, F1_train: 0.9126284875183553 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.05it/s]
# epoch: 32/50, train_loss: 3.4349803924560547, F1_train: 0.9134897360703812 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.06it/s]
# epoch: 33/50, train_loss: 3.434971570968628, F1_train: 0.913919413919414 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.05it/s]
# epoch: 34/50, train_loss: 3.4349710941314697, F1_train: 0.914134016843647 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  3.01it/s]
# epoch: 35/50, train_loss: 3.4349701404571533, F1_train: 0.9143484626647145 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.08it/s]
# epoch: 36/50, train_loss: 3.434990167617798, F1_train: 0.9145627515550677 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.08it/s]
# epoch: 37/50, train_loss: 3.4349703788757324, F1_train: 0.9152046783625731 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.08it/s]
# epoch: 38/50, train_loss: 3.4349794387817383, F1_train: 0.9154183412495434 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.08it/s]
# epoch: 39/50, train_loss: 3.4349775314331055, F1_train: 0.9154183412495434 F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.06it/s]
# epoch: 40/50, train_loss: 3.4349803924560547, F1_train: 0.9156318480642804 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 41/50, train_loss: 3.43497371673584, F1_train: 0.9156318480642804 F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 42/50, train_loss: 3.4349749088287354, F1_train: 0.916058394160584 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 43/50, train_loss: 3.4349639415740967, F1_train: 0.916058394160584 F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.06it/s]
# epoch: 44/50, train_loss: 3.434976816177368, F1_train: 0.916058394160584 F1_val: 1.0
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 45/50, train_loss: 3.4349756240844727, F1_train: 0.9162714337832908 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 46/50, train_loss: 3.434965133666992, F1_train: 0.9164843180160466 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.06it/s]
# epoch: 47/50, train_loss: 3.434985399246216, F1_train: 0.9164843180160466 F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 48/50, train_loss: 3.434983253479004, F1_train: 0.9164843180160466 F1_val: 1.0
# train score not improving  going to wait state 2
# val score not improving  going to wait state 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 49/50, train_loss: 3.4349734783172607, F1_train: 0.9166970470288005 F1_val: 1.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:32<00:00,  3.07it/s]
# epoch: 50/50, train_loss: 3.434968948364258, F1_train: 0.9166970470288005 F1_val: 1.0
# train score not improving  going to wait state 1
# val score not improving  going to wait state 1
# classification report for training:
# [[1600    0    0]
#  [   0 1143  457]
#  [   0    0    0]]
# 85.72
# f1_weighted: 0.9166970470288005, f1_macro: 0.611131364685867, f1_micro: 0.8571875, f_measure: {'Known': 91.6697, 'Open': 0, 'F1-score': 61.1131}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1600
#            1       1.00      0.71      0.83      1600
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.86      3200
#    macro avg       0.67      0.57      0.61      3200
# weighted avg       1.00      0.86      0.92      3200
#
# classification report for test data:
# [[193   0   0]
#  [  0 196   0]
#  [  0   0 187]]
# 100.0
# f1_weighted: 1.0, f1_macro: 1.0, f1_micro: 1.0, f_measure: {'Known': 100.0, 'Open': 100.0, 'F1-score': 100.0}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       193
#            1       1.00      1.00      1.00       196
#            2       1.00      1.00      1.00       187
#
#     accuracy                           1.00       576
#    macro avg       1.00      1.00      1.00       576
# weighted avg       1.00      1.00      1.00       576
#
# the color map for the classes, here index postion are the class number: ['green', 'blue', 'yellow', 'pink', 'black', 'orange', 'purple', 'red', 'beige', 'brown', 'gray', 'cyan', 'magenta']
# INFO:tensorflow:Assets written to: ram://480ad4b2-5607-4193-adb3-f0fbd737d61c/assets

# %%
oset.plot_centroids(use_labels=oset.total_preds, centroid_black=True)

# %%
oset.plot_centroids(use_labels=oset.total_preds, centroid_black=True, tsne_perplexity=17)

# %%
for i in (13, 17, 30, 40, 45, 86):
    print('perpexity :', i)    
    oset.plot_centroids(use_labels=oset.total_preds, centroid_black=True, tsne_perplexity=i)
# Out:
# perpexity : 13
# perpexity : 17
# perpexity : 30
# perpexity : 40
# perpexity : 45
# perpexity : 86
